# %%
import pandas as pd
from datetime import datetime, timedelta, timezone
import os
from PyEIS import *
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rcParams
import csv
import glob
import statistics
from sklearn.linear_model import LinearRegression
from scipy.stats import linregress
import math

#from matplotlib.pyplot import rc
#rc('text',usetex=True)
#rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']},size='16')
#rc('text.latex', preamble=r'\usepackage{sfmath}')

#set font to Arial
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']


#Put Post-Stabilization Temperature Data into a dataframe
#This file path should go to the *post-stabilization* .txt file that Quincy puts out
file_path = "C:/Users/austi/OneDrive - Colorado School of Mines/Research/Data/EIS/Data/02_05_2024/2_5_2024_Quincy Data_1-107APellet2_1-114Pellet1/Quincy Data Files/Post-Stabilization Temperature Data.txt"
df = pd.read_csv(file_path)

# Define the time column title in the data file as time
Time = 'Time (Day Month Year Hours:Minutes:Seconds AM/PM)'

# Convert the 'Time' column to datetime format
df[Time] = pd.to_datetime(df[Time], format='%d %B %Y %I:%M:%S %p')
#print(df[Time])

#WAS IT DAYLIGHT SAVINGS TIME WHEN YOU COLLECTED YOUR DATA? if yes, set daylight_savings to true. If not, set to false.
daylight_savings=True

if daylight_savings==True:
    #for daylight time (mid March - mid November):
    df['EpochTime'] = ((df[Time] - pd.Timestamp("1970-01-01")) // pd.Timedelta('1s')) + 21600

if daylight_savings==False:
    # for standard time (mid November - mid March):
    df['EpochTime'] = ((df[Time] - pd.Timestamp("1970-01-01")) // pd.Timedelta('1s')) + 25200

# Define the target temperatures, these should be whatever temperatures you dwelled at. 
target_temperatures = [30, 35, 45, 55, 65, 75, 85, 95]

# Create a dictionary to store the first and last time for each temperature
temperature_ranges = {temp: {'first_time': None, 'last_time': None} for temp in target_temperatures}

# Iterate through the DataFrame rows
for index, row in df.iterrows():
    temperature = row['Oven Temperature (degrees C)']

    # Check if the temperature is within 0.5 degrees of any target temperature
    for target_temp in target_temperatures:
        if abs(temperature - target_temp) <= 0.5:
            if temperature_ranges[target_temp]['first_time'] is None:
                temperature_ranges[target_temp]['first_time'] = row['EpochTime']
            temperature_ranges[target_temp]['last_time'] = row['EpochTime']

# Create a DataFrame from the temperature_ranges dictionary
temperature_ranges_df = pd.DataFrame(temperature_ranges.items(), columns=['Temperature', 'TimeRange'])

# Split the 'TimeRange' column into 'Start' and 'End' columns
temperature_ranges_df[['Start', 'End']] = pd.DataFrame(temperature_ranges_df['TimeRange'].tolist(), index=temperature_ranges_df.index)

# Drop the original 'TimeRange' column
temperature_ranges_df = temperature_ranges_df.drop('TimeRange', axis=1)

# Print the resulting DataFrame
print(temperature_ranges_df)
# Out:
#    Temperature       Start         End
# 0           30  1707162875  1707168439
# 1           35  1707174400  1707179298
# 2           45  1707184877  1707191036
# 3           55  1707195863  1707202281
# 4           65  1707208369  1707214553
# 5           75  1707219003  1707225633
# 6           85  1707229019  1707235571
# 7           95  1707238410  1707245242

# %%
#INPUT DIAMETER AND HEIGHT OF PELLET HERE!
#diameter in mm
diameter = 6
#pellet height in mm
height = 2.095

#Errors in the thickness and height, generally no need to change this.
#err in pellet diameter (mm)
diameter_err=0.01
#err in pellet height (mm)
height_err=0.001

# %%
# Specify the folder path where '.DTA' files are located
# Note that this is the FOLDER with all your .DTA files.
folder_path = "C:/Users/austi/OneDrive - Colorado School of Mines/Research/Data/EIS/Data/02_05_2024/02_05_2024_1_107A_Pellet2_TempEIS/"

# Function to list '.DTA' files between specified timestamps
def list_files_between_timestamps(folder_path, start_timestamp, end_timestamp):

    file_list = []

    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)

        # Check if the file is a '.DTA' file
        if filename.endswith('.DTA') and os.path.isfile(file_path):
            # Get the file's last modification timestamp
            file_timestamp = os.path.getmtime(file_path)
            #print(start_timestamp, end_timestamp, file_timestamp)
            if start_timestamp <= file_timestamp <= end_timestamp:
                file_list.append(filename)

    return file_list

# %%
# Use loc to filter rows based on the temperature value
#start_result = temperature_ranges_df.loc[temperature_ranges_df['Temperature'] == search_temp, ['Start']]
#end_result = temperature_ranges_df.loc[temperature_ranges_df['Temperature'] == search_temp, ['End']]

# Print the result
#print(start_result)

files_found_dict = {}

#Iterate through target temperatures
for search_temp in target_temperatures:
    start_result = temperature_ranges_df.loc[temperature_ranges_df['Temperature'] == search_temp, ['Start']]
    end_result = temperature_ranges_df.loc[temperature_ranges_df['Temperature'] == search_temp, ['End']]
        # Assuming start_result and end_result are datetime objects
    start_time = start_result.iloc[0]['Start']
    end_time = end_result.iloc[0]['End']
    # Print intermediate results for troubleshooting
    #print(f"Search Temperature: {search_temp}")
    #print("Start Time:")
    #print(start_time)
    #print("End Time:")
    #print(end_time)
    #YEET the files from between the start and end times into a dictionary
    files_found_dict[search_temp] = list_files_between_timestamps(folder_path, start_time, end_time)
    #print(files_found_dict)
# Print the results
    
print(files_found_dict[30])
    # Print the results for each temperature
    #print(f"Results for Temperature {search_temp}:")
    #print("Start:", start_result.iloc[0]['Start'] if not start_result.empty else "Not found")
    #print("End:", end_result.iloc[0]['End'] if not end_result.empty else "Not found")
    #print()
# Out:
# ['EISPOT_#1.DTA', 'EISPOT_#2.DTA', 'EISPOT_#3.DTA', 'EISPOT_#4.DTA', 'EISPOT_#5.DTA', 'EISPOT_#6.DTA', 'EISPOT_#7.DTA']

# %%
# Common parameters for all files

#The values here are the highest frequency and lowest frequency that are included. 
common_params = {
    'mask': [10**7, 10000]}

# Dictionary to store the EIS_exp instances
all_experiments = {}

# Iterate through the keys in files_found_dict
for temp, file_list in files_found_dict.items():
    temp_experiments = {}
    
    # Iterate through the file list for each temperature
    for idx, filename in enumerate(file_list, start=1):
        params = {'path': folder_path, 'data': [filename]}
        params.update(common_params)
        
        
        #var_name = f"Ex{idx}_Temp{temp}"
        
        # Call the EIS_exp function and store the instance in the dictionary, dictionary has two keys
        temp_experiments[idx] = EIS_exp(**params)
    
        # Store the experiments for each temperature in the overall dictionary
        #this generates the 'all_experiments' dictionary with a two part key. The first part of the key is the temperature, while the second part of the key is the replicate at that temperature.
        all_experiments[temp,idx] = temp_experiments[idx]

# Print the resulting dictionary of experiments
print(all_experiments)
# Out:
# {(30, 1): <PyEIS.PyEIS.EIS_exp object at 0x000001D126B55610>, (30, 2): <PyEIS.PyEIS.EIS_exp object at 0x000001D126B55160>, (30, 3): <PyEIS.PyEIS.EIS_exp object at 0x000001D12BF6BA30>, (30, 4): <PyEIS.PyEIS.EIS_exp object at 0x000001D12BF6BA00>, (30, 5): <PyEIS.PyEIS.EIS_exp object at 0x000001D126A82520>, (30, 6): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C09F1C0>, (30, 7): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C09FB80>, (35, 1): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C0A6040>, (35, 2): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C0A63D0>, (35, 3): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C0AF670>, (35, 4): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C0BEF40>, (35, 5): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C0BEBE0>, (35, 6): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C0C5400>, (35, 7): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C0C57C0>, (35, 8): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C0D9EE0>, (35, 9): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C0D9D60>, (45, 1): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C0E6340>, (45, 2): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C0E6790>, (45, 3): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C0CE3D0>, (45, 4): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C0FA100>, (45, 5): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C0FABE0>, (45, 6): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C102D60>, (45, 7): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C102B50>, (45, 8): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C1066A0>, (45, 9): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C119640>, (45, 10): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C119BE0>, (45, 11): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C120C70>, (55, 1): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C1200A0>, (55, 2): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C131EE0>, (55, 3): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C131D60>, (55, 4): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C140310>, (55, 5): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C140760>, (55, 6): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C128BB0>, (55, 7): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C14E400>, (55, 8): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C14ECA0>, (55, 9): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C162FA0>, (55, 10): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C1625B0>, (55, 11): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C148400>, (55, 12): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C170190>, (65, 1): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C170B80>, (65, 2): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C17C040>, (65, 3): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C17C490>, (65, 4): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C187BB0>, (65, 5): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C187E50>, (65, 6): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C199BB0>, (65, 7): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C199700>, (65, 8): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C191850>, (65, 9): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C1A8EB0>, (65, 10): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C1A8D90>, (65, 11): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C1B8340>, (75, 1): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C1B8790>, (75, 2): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C19FA60>, (75, 3): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C1C8100>, (75, 4): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C1C8BE0>, (75, 5): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C1CED60>, (75, 6): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C1CEB50>, (75, 7): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C1D36A0>, (75, 8): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C1E3700>, (75, 9): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C1E3C10>, (75, 10): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C1EDCA0>, (75, 11): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C1ED8E0>, (75, 12): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C1D7EE0>, (85, 1): <PyEIS.PyEIS.EIS_exp object at 0x000001D12C1D7DF0>, (85, 2): <PyEIS.PyEIS.EIS_exp object at 0x000001D12D1D8B50>, (85, 3): <PyEIS.PyEIS.EIS_exp object at 0x000001D12D1D86A0>, (85, 4): <PyEIS.PyEIS.EI ...

# %%
#In order to fit the experimental data, a parameter space is needed for the EIS_fit() function with initial guesses
#for each parameter including lower and upper bounds.
#You may want to rerun this step until the data fits well.
#Adjusting starting parameters to match your data will give the best results

#If this section is confusing to you or you are struggling with equivalent circuit modeling, check out:
#DOI: 10.1021/acsmeasuresciau.2c00070
#DOI: 10.1002/celc.202100108

#do you want to do a sequential fit where the results of the previous fit are used as the starting values for the next one?
#This is particularly useful for temperature dependent datasets to allow for the parameter drift over different temperatures
sequentialfit='yes'
params= Parameters() #creates the parameter space
#the following guesses will need to be adjusted based on your data as well as the equivalent circuit to be fit
#the following equivalent circuit is the Rs_(RQ)1_Q circuit

#Rs_guess is the leading resistor that accounts for the resistance of our leads and equipment
#This is generally 0 or close to 0 for Austin's samples. 
#If your whole semicircle is visible, a good starting value is where the left hand side of the semicircle touches down on the z-real axis
Rs_guess = 0
params.add('Rs', value=Rs_guess, min=0, max=1)

#R1_guess is the bulk resistance that is in the RQ element
#A good starting guess is where the right side of your semicircle comes closest to the z-real axis.
R1_guess = 500
params.add('R1', value=R1_guess, min=0, max=10**10)

#n1_guess represents the ideality of your semicircle
#if it's squashed, use a lower starting value, if it's gorgeous, use a value closer to 1
n1_guess = 0.7
params.add('n1', value=n1_guess, min=0.6, max=1) #do not change min max values of n otherwise they become meaningless

#fs1_guess represents the characteristic frequency for the semicircle
#this is the frequency corresponding to the maximum z-imaginary value for your semicircle
fs1_guess = 9000000
params.add('fs1', value=fs1_guess, min=fs1_guess*.001, max=fs1_guess*100)

#n_guess and Q-guess represent the ideality of the capacitor-like behavior of the capacitive tail
n_guess = 0.7
params.add('n', value=n1_guess, min=0.6, max=1) #do not change min max values of n otherwise they become meaningless
Q_guess = 10**-7
params.add('Q', value=Q_guess, min=Q_guess*0.001, max=Q_guess*1000)

#code below actually does the fit, change the circuit to what you need with circuit = ''
#experiments['Ex1'].EIS_fit(params=params, circuit='R-RQ-Q')
# Dictionary to store fit results
fit_results = {}

# Iterate through the outer dictionary (temperature-wise experiments)
for key, exp_instance in all_experiments.items():
    temp_fit_results = {}

    # Iterate through the inner dictionary (individual experiments for each temperature)
    #for exp_name, exp_instance in temp_experiments.items():
    fit_result = exp_instance.EIS_fit(params=params, circuit='R-RQ-Q')
    temp_fit_results[key] = fit_result
    print(f'Start R1 value for temp {key[0]}C, replicate {key[1]}:', params['R1'].value)
    print(f'Refined R1 value for temp {key[0]}C, replicate {key[1]}:', exp_instance.fit_R1[0])
    if sequentialfit == 'yes':
        params['Rs'].value = exp_instance.fit_Rs[0]
        params['R1'].value = exp_instance.fit_R1[0]
        params['n1'].value = exp_instance.fit_n1[0]
        params['fs1'].value = exp_instance.fit_fs1[0]
        params['n'].value = exp_instance.fit_n[0]
        params['Q'].value = exp_instance.fit_Q[0]
    # Store the fit results for each temperature
    fit_results[key] = temp_fit_results

# Print the overall fit results
print(fit_results)
# Out:
# C:\Users\austi\anaconda3\lib\site-packages\lmfit\minimizer.py:493: RuntimeWarning: ignoring `maxfev` argument to `Minimizer()`. Use `max_nfev` instead.
#   warnings.warn(maxeval_warning.format(maxnfev_alias, 'Minimizer'),
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 1054
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 3.17429720
#     reduced chi-square = 0.07935743
#     Akaike info crit   = -110.983537
#     Bayesian info crit = -100.011688
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at boundary
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   400.390577 (init = 500)
#     n1:   0.99999967 (init = 0.7)
#     fs1:  25248336.1 (init = 9000000)
#     n:    0.68185923 (init = 0.7)
#     Q:    2.0276e-07 (init = 1e-07)
# None
# Start R1 value for temp 30C, replicate 1: 500
# Refined R1 value for temp 30C, replicate 1: 400.3905768046323
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 536
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 2.75345136
#     reduced chi-square = 0.06883628
#     Akaike info crit   = -117.526167
#     Bayesian info crit = -106.554318
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     n1:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   399.549559 (init = 400.3906)
#     n1:   0.99999533 (init = 0.9999997)
#     fs1:  25713294.6 (init = 2.524834e+07)
#     n:    0.68076318 (init = 0.6818592)
#     Q:    2.0830e-07 (init = 2.027587e-07)
# None
# Start R1 value for temp 30C, replicate 2: 400.3905768046323
# Refined R1 value for temp 30C, replicate 2: 399.5495589936837
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 11
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 3.93491271
#     reduced chi-square = 0.09837282
#     Akaike info crit   = -101.102624
#     Bayesian info crit = -90.1307757
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     R1:   at initial value
#     n1:   at initial value
#     n1:   at boundary
#     fs1:  at initial value
#     n:    at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   399.549559 (init = 399.5496)
#     n1:   0.99999533 (init = 0.9999953)
#     fs1:  25713294.6 (init = 2.571329e+07)
#     n:    0.68076318 (init = 0.6807632)
#     Q:    2.0830e-07 (init = 2.082971e-07)
# None
# Start R1 value for temp 30C, replicate 3: 399.5495589936837
# Refined R1 value for temp 30C, replicate 3: 399.5495589936837
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 3593
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 2.33449045
#     reduced chi-square = 0.05836226
#     Akaike info crit   = -125.118997
#     Bayesian info crit = -114.147148
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   399.987338 (init = 399.5496)
#     n1:   0.99994998 (init = 0.9999953)
#     fs1:  25106229.0 (init = 2.571329e+07)
#     n:    0.67992126 (init = 0.6807632)
#     Q:    2.1514e-07 (init = 2.082971e-07)
# None
# Start R1 value for temp 30C, replicate 4: 399.5495589936837
# Refined R1 value for temp 30C, replicate 4: 399.9873382509733
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 1959
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 2.09004285
#     reduced chi-square = 0.05225107
#     Akaike info crit   = -130.207014
#     Bayesian info crit = -119.235166
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   399.556047 (init = 399.9873)
#     n1:   0.99997090 (init = 0.99995)
#     fs1:  25078584.6 (init = 2.510623e+07)
#     n:    0.67781313 (init = 0.6799213)
#     Q:    2.2241e-07 (init = 2.151361e-07)
# None
# Start R1 value for temp 30C, replicate 5: 399.9873382509733
# Refined R1 value for temp 30C, replicate 5: 399.5560465819281
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 11
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 2.47865161
#     reduced chi-square = 0.06196629
#     Akaike info crit   = -122.362628
#     Bayesian info crit = -111.390779
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     R1:   at initial value
#     n1:   at initial value
#     fs1:  at initial value
#     n:    at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   399.556047 (init = 399.556)
#     n1:   0.99997090 (init = 0.9999709)
#     fs1:  25078584.6 (init = 2.507858e+07)
#     n:    0.67781313 (init = 0.6778131)
#     Q:    2.2241e-07 (init = 2.224107e-07)
# None
# Start R1 value for temp 30C, replicate 6: 399.5560465819281
# Refined R1 value for temp 30C, replicate 6: 399.5560465819281
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 11
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 3.83562792
#     reduced chi-square = 0.09589070
#     Akaike info crit   = -102.278179
#     Bayesian info crit = -91.3063307
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     R1:   at initial value
#     n1:   at initial value
#     fs1:  at initial value
#     n:    at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   399.556047 (init = 399.556)
#     n1:   0.99997090 (init = 0.9999709)
#     fs1:  25078584.6 (init = 2.507858e+07)
#     n:    0.67781313 (init = 0.6778131)
#     Q:    2.2241e-07 (init = 2.224107e-07)
# None
# Start R1 value for temp 30C, replicate 7: 399.5560465819281
# Refined R1 value for temp 30C, replicate 7: 399.5560465819281
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 517
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.40021774
#     reduced chi-square = 0.01000544
#     Akaike info crit   = -206.241845
#     Bayesian info crit = -195.269997
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at boundary
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   325.935336 (init = 399.556)
#     n1:   0.99999947 (init = 0.9999709)
#     fs1:  29003380.7 (init = 2.507858e+07)
#     n:    0.65970716 (init = 0.6778131)
#     Q:    3.3982e-07 (init = 2.224107e-07)
# None
# Start R1 value for temp 35C, replicate 1: 399.5560465819281
# Refined R1 value for temp 35C, replicate 1: 325.9353364981621
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 62
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.39626266
#     reduced chi-square = 0.00990657
#     Akaike info crit   = -206.698693
#     Bayesian info crit = -195.726844
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     n1:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   327.250061 (init = 325.9353)
#     n1:   0.99999135 (init = 0.9999995)
#     fs1:  28367272.3 (init = 2.900338e+07)
#     n:    0.65994478 (init = 0.6597072)
#     Q:    3.4096e-07 (init = 3.398204e-07)
# None
# Start R1 value for temp 35C, replicate 2: 325.9353364981621
# Refined R1 value for temp 35C, replicate 2: 327.25006093858866
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 10
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.50199314
#     reduced chi-square = 0.01254983
#     Akaike info crit   = -195.819270
#     Bayesian info crit = -184.847422
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     R1:   at initial value
#     n1:   at initial value
#     n1:   at boundary
#     fs1:  at initial value
#     n:    at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   327.250061 (init = 327.2501)
#     n1:   0.99999135 (init = 0.9999913)
#     fs1:  28367272.3 (init = 2.836727e+07)
#     n:    0.65994478 (init = 0.6599448)
#     Q:    3.4096e-07 (init = 3.409582e-07)
# None
# Start R1 value for temp 35C, replicate 3: 327.25006093858866
# Refined R1 value for temp 35C, replicate 3: 327.25006093858866
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 10
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.67201723
#     reduced chi-square = 0.01680043
#     Akaike info crit   = -182.401184
#     Bayesian info crit = -171.429336
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     R1:   at initial value
#     n1:   at initial value
#     n1:   at boundary
#     fs1:  at initial value
#     n:    at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   327.250061 (init = 327.2501)
#     n1:   0.99999135 (init = 0.9999913)
#     fs1:  28367272.3 (init = 2.836727e+07)
#     n:    0.65994478 (init = 0.6599448)
#     Q:    3.4096e-07 (init = 3.409582e-07)
# None
# Start R1 value for temp 35C, replicate 4: 327.25006093858866
# Refined R1 value for temp 35C, replicate 4: 327.25006093858866
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 211
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.46493754
#     reduced chi-square = 0.01162344
#     Akaike info crit   = -199.346706
#     Bayesian info crit = -188.374857
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     n1:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   327.907408 (init = 327.2501)
#     n1:   0.99999997 (init = 0.9999913)
#     fs1:  27175273.2 (init = 2.836727e+07)
#     n:    0.65953415 (init = 0.6599448)
#     Q:    3.4907e-07 (init = 3.409582e-07)
# None
# Start R1 value for temp 35C, replicate 5: 327.25006093858866
# Refined R1 value for temp 35C, replicate 5: 327.90740789323536
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 96
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.56929890
#     reduced chi-square = 0.01423247
#     Akaike info crit   = -190.031589
#     Bayesian info crit = -179.059741
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     n1:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   321.986833 (init = 327.9074)
#     n1:   1.00000000 (init = 1)
#     fs1:  26048526.1 (init = 2.717527e+07)
#     n:    0.65976442 (init = 0.6595341)
#     Q:    3.5529e-07 (init = 3.490702e-07)
# None
# Start R1 value for temp 35C, replicate 6: 327.90740789323536
# Refined R1 value for temp 35C, replicate 6: 321.98683330708633
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 81
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.64891661
#     reduced chi-square = 0.01622292
#     Akaike info crit   = -184.010253
#     Bayesian info crit = -173.038405
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     n1:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   320.456567 (init = 321.9868)
#     n1:   0.99999995 (init = 1)
#     fs1:  24995105.0 (init = 2.604853e+07)
#     n:    0.66009161 (init = 0.6597644)
#     Q:    3.5860e-07 (init = 3.552868e-07)
# None
# Start R1 value for temp 35C, replicate 7: 321.98683330708633
# Refined R1 value for temp 35C, replicate 7: 320.45656739310147
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 72
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.66744388
#     reduced chi-square = 0.01668610
#     Akaike info crit   = -182.715303
#     Bayesian info crit = -171.743454
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   321.705734 (init = 320.4566)
#     n1:   0.97725085 (init = 1)
#     fs1:  26186234.0 (init = 2.499511e+07)
#     n:    0.66026792 (init = 0.6600916)
#     Q:    3.5984e-07 (init = 3.585952e-07)
# None
# Start R1 value for temp 35C, replicate 8: 320.45656739310147
# Refined R1 value for temp 35C, replicate 8: 321.70573427414695
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 57
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.67868174
#     reduced chi-square = 0.01696704
#     Akaike info crit   = -181.947241
#     Bayesian info crit = -170.975393
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   323.163914 (init = 321.7057)
#     n1:   0.96176395 (init = 0.9772509)
#     fs1:  27126489.9 (init = 2.618623e+07)
#     n:    0.66038770 (init = 0.6602679)
#     Q:    3.6030e-07 (init = 3.59843e-07)
# None
# Start R1 value for temp 35C, replicate 9: 321.70573427414695
# Refined R1 value for temp 35C, replicate 9: 323.1639139622544
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 141
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 10.1472433
#     reduced chi-square = 0.25368108
#     Akaike info crit   = -57.5262089
#     Bayesian info crit = -46.5543605
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at boundary
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   271.539594 (init = 323.1639)
#     n1:   0.60000126 (init = 0.9617639)
#     fs1:  28489284.6 (init = 2.712649e+07)
#     n:    0.70874967 (init = 0.6603877)
#     Q:    2.8820e-07 (init = 3.602979e-07)
# None
# Start R1 value for temp 45C, replicate 1: 323.1639139622544
# Refined R1 value for temp 45C, replicate 1: 271.5395935881659
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 554
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 10.2360730
#     reduced chi-square = 0.25590183
#     Akaike info crit   = -57.1252738
#     Bayesian info crit = -46.1534254
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   270.856750 (init = 271.5396)
#     n1:   0.60000724 (init = 0.6000013)
#     fs1:  27885118.7 (init = 2.848928e+07)
#     n:    0.70958078 (init = 0.7087497)
#     Q:    2.8885e-07 (init = 2.882039e-07)
# None
# Start R1 value for temp 45C, replicate 2: 271.5395935881659
# Refined R1 value for temp 45C, replicate 2: 270.8567498066472
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 407
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 10.2386980
#     reduced chi-square = 0.25596745
#     Akaike info crit   = -57.1134791
#     Bayesian info crit = -46.1416307
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   273.388397 (init = 270.8567)
#     n1:   0.60000748 (init = 0.6000072)
#     fs1:  27657837.6 (init = 2.788512e+07)
#     n:    0.70997206 (init = 0.7095808)
#     Q:    2.8873e-07 (init = 2.888548e-07)
# None
# Start R1 value for temp 45C, replicate 3: 270.8567498066472
# Refined R1 value for temp 45C, replicate 3: 273.3883974759266
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 274
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 11.3902427
#     reduced chi-square = 0.28475607
#     Akaike info crit   = -52.2106783
#     Bayesian info crit = -41.2388300
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   269.494148 (init = 273.3884)
#     n1:   0.60002304 (init = 0.6000075)
#     fs1:  27016666.8 (init = 2.765784e+07)
#     n:    0.71129043 (init = 0.7099721)
#     Q:    2.9161e-07 (init = 2.887323e-07)
# None
# Start R1 value for temp 45C, replicate 4: 273.3883974759266
# Refined R1 value for temp 45C, replicate 4: 269.4941475533952
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 353
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 12.3123479
#     reduced chi-square = 0.30780870
#     Akaike info crit   = -48.6297821
#     Bayesian info crit = -37.6579337
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at boundary
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   266.711928 (init = 269.4941)
#     n1:   0.60000081 (init = 0.600023)
#     fs1:  23654961.0 (init = 2.701667e+07)
#     n:    0.72502929 (init = 0.7112904)
#     Q:    2.5622e-07 (init = 2.916087e-07)
# None
# Start R1 value for temp 45C, replicate 5: 269.4941475533952
# Refined R1 value for temp 45C, replicate 5: 266.7119275434615
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 480
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 12.7936487
#     reduced chi-square = 0.31984122
#     Akaike info crit   = -46.8658569
#     Bayesian info crit = -35.8940086
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     n1:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   263.023306 (init = 266.7119)
#     n1:   0.60000052 (init = 0.6000008)
#     fs1:  22561833.1 (init = 2.365496e+07)
#     n:    0.73063411 (init = 0.7250293)
#     Q:    2.4630e-07 (init = 2.562212e-07)
# None
# Start R1 value for temp 45C, replicate 6: 266.7119275434615
# Refined R1 value for temp 45C, replicate 6: 263.0233059131015
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 12
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 16.3496775
#     reduced chi-square = 0.40874194
#     Akaike info crit   = -35.5839284
#     Bayesian info crit = -24.6120801
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     R1:   at initial value
#     n1:   at initial value
#     n1:   at boundary
#     fs1:  at initial value
#     n:    at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   263.023306 (init = 263.0233)
#     n1:   0.60000052 (init = 0.6000005)
#     fs1:  22561833.1 (init = 2.256183e+07)
#     n:    0.73063411 (init = 0.7306341)
#     Q:    2.4630e-07 (init = 2.463032e-07)
# None
# Start R1 value for temp 45C, replicate 7: 263.0233059131015
# Refined R1 value for temp 45C, replicate 7: 263.0233059131015
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 586
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 12.8885339
#     reduced chi-square = 0.32221335
#     Akaike info crit   = -46.5259528
#     Bayesian info crit = -35.5541044
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     n1:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   262.957345 (init = 263.0233)
#     n1:   0.60000026 (init = 0.6000005)
#     fs1:  21928179.9 (init = 2.256183e+07)
#     n:    0.73553829 (init = 0.7306341)
#     Q:    2.3806e-07 (init = 2.463032e-07)
# None
# Start R1 value for temp 45C, replicate 8: 263.0233059131015
# Refined R1 value for temp 45C, replicate 8: 262.9573453427625
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 744
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 12.9912574
#     reduced chi-square = 0.32478143
#     Akaike info crit   = -46.1607796
#     Bayesian info crit = -35.1889312
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     n1:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   261.678296 (init = 262.9573)
#     n1:   0.60000318 (init = 0.6000003)
#     fs1:  21671756.4 (init = 2.192818e+07)
#     n:    0.73765136 (init = 0.7355383)
#     Q:    2.3519e-07 (init = 2.380633e-07)
# None
# Start R1 value for temp 45C, replicate 9: 262.9573453427625
# Refined R1 value for temp 45C, replicate 9: 261.6782956987862
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 77
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 13.3583633
#     reduced chi-square = 0.33395908
#     Akaike info crit   = -44.8789421
#     Bayesian info crit = -33.9070937
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   258.929537 (init = 261.6783)
#     n1:   0.60001407 (init = 0.6000032)
#     fs1:  21631013.3 (init = 2.167176e+07)
#     n:    0.73843947 (init = 0.7376514)
#     Q:    2.3711e-07 (init = 2.351928e-07)
# None
# Start R1 value for temp 45C, replicate 10: 261.6782956987862
# Refined R1 value for temp 45C, replicate 10: 258.9295372557032
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 104
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 13.5050869
#     reduced chi-square = 0.33762717
#     Akaike info crit   = -44.3764488
#     Bayesian info crit = -33.4046004
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   256.929615 (init = 258.9295)
#     n1:   0.60001341 (init = 0.6000141)
#     fs1:  21584313.6 (init = 2.163101e+07)
#     n:    0.73908587 (init = 0.7384395)
#     Q:    2.3880e-07 (init = 2.371096e-07)
# None
# Start R1 value for temp 45C, replicate 11: 258.9295372557032
# Refined R1 value for temp 45C, replicate 11: 256.9296153609457
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 874
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 9.10356479
#     reduced chi-square = 0.22758912
#     Akaike info crit   = -62.5188649
#     Bayesian info crit = -51.5470166
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at boundary
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   219.596170 (init = 256.9296)
#     n1:   0.60000095 (init = 0.6000134)
#     fs1:  17338077.0 (init = 2.158431e+07)
#     n:    0.80279065 (init = 0.7390859)
#     Q:    1.3589e-07 (init = 2.388028e-07)
# None
# Start R1 value for temp 55C, replicate 1: 256.9296153609457
# Refined R1 value for temp 55C, replicate 1: 219.59617013678212
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 2484
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 7.49005347
#     reduced chi-square = 0.18725134
#     Akaike info crit   = -71.4930112
#     Bayesian info crit = -60.5211628
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     n1:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   208.430908 (init = 219.5962)
#     n1:   0.60000515 (init = 0.6000009)
#     fs1:  18311498.9 (init = 1.733808e+07)
#     n:    0.81041549 (init = 0.8027906)
#     Q:    1.2995e-07 (init = 1.358883e-07)
# None
# Start R1 value for temp 55C, replicate 2: 219.59617013678212
# Refined R1 value for temp 55C, replicate 2: 208.4309080885305
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 12
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 14.2391501
#     reduced chi-square = 0.35597875
#     Akaike info crit   = -41.9417242
#     Bayesian info crit = -30.9698759
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     R1:   at initial value
#     n1:   at initial value
#     n1:   at boundary
#     fs1:  at initial value
#     n:    at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   208.430908 (init = 208.4309)
#     n1:   0.60000515 (init = 0.6000052)
#     fs1:  18311498.9 (init = 1.83115e+07)
#     n:    0.81041549 (init = 0.8104155)
#     Q:    1.2995e-07 (init = 1.299492e-07)
# None
# Start R1 value for temp 55C, replicate 3: 208.4309080885305
# Refined R1 value for temp 55C, replicate 3: 208.4309080885305
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 12
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 16.2597246
#     reduced chi-square = 0.40649312
#     Akaike info crit   = -35.8377105
#     Bayesian info crit = -24.8658622
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     R1:   at initial value
#     n1:   at initial value
#     n1:   at boundary
#     fs1:  at initial value
#     n:    at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   208.430908 (init = 208.4309)
#     n1:   0.60000515 (init = 0.6000052)
#     fs1:  18311498.9 (init = 1.83115e+07)
#     n:    0.81041549 (init = 0.8104155)
#     Q:    1.2995e-07 (init = 1.299492e-07)
# None
# Start R1 value for temp 55C, replicate 4: 208.4309080885305
# Refined R1 value for temp 55C, replicate 4: 208.4309080885305
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 2005
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 5.28469775
#     reduced chi-square = 0.13211744
#     Akaike info crit   = -87.5359946
#     Bayesian info crit = -76.5641462
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     n1:   at boundary
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   201.346506 (init = 208.4309)
#     n1:   0.60000433 (init = 0.6000052)
#     fs1:  18699177.5 (init = 1.83115e+07)
#     n:    0.82413746 (init = 0.8104155)
#     Q:    1.1533e-07 (init = 1.299492e-07)
# None
# Start R1 value for temp 55C, replicate 5: 208.4309080885305
# Refined R1 value for temp 55C, replicate 5: 201.34650557945832
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 11
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 18.6387958
#     reduced chi-square = 0.46596990
#     Akaike info crit   = -29.5562248
#     Bayesian info crit = -18.5843765
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     R1:   at initial value
#     n1:   at initial value
#     n1:   at boundary
#     fs1:  at initial value
#     n:    at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   201.346506 (init = 201.3465)
#     n1:   0.60000433 (init = 0.6000043)
#     fs1:  18699177.5 (init = 1.869918e+07)
#     n:    0.82413746 (init = 0.8241375)
#     Q:    1.1533e-07 (init = 1.15334e-07)
# None
# Start R1 value for temp 55C, replicate 6: 201.34650557945832
# Refined R1 value for temp 55C, replicate 6: 201.34650557945832
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 12
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 50.7765270
#     reduced chi-square = 1.26941318
#     Akaike info crit   = 16.5444681
#     Bayesian info crit = 27.5163165
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     R1:   at initial value
#     n1:   at initial value
#     n1:   at boundary
#     fs1:  at initial value
#     n:    at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   201.346506 (init = 201.3465)
#     n1:   0.60000433 (init = 0.6000043)
#     fs1:  18699177.5 (init = 1.869918e+07)
#     n:    0.82413746 (init = 0.8241375)
#     Q:    1.1533e-07 (init = 1.15334e-07)
# None
# Start R1 value for temp 55C, replicate 7: 201.34650557945832
# Refined R1 value for temp 55C, replicate 7: 201.34650557945832
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 659
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 3.38688754
#     reduced chi-square = 0.08467219
#     Akaike info crit   = -108.001581
#     Bayesian info crit = -97.0297328
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     n1:   at boundary
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   188.146510 (init = 201.3465)
#     n1:   0.60000098 (init = 0.6000043)
#     fs1:  19709992.5 (init = 1.869918e+07)
#     n:    0.83904592 (init = 0.8241375)
#     Q:    1.0185e-07 (init = 1.15334e-07)
# None
# Start R1 value for temp 55C, replicate 8: 201.34650557945832
# Refined R1 value for temp 55C, replicate 8: 188.14651003840055
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 570
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 3.03645542
#     reduced chi-square = 0.07591139
#     Akaike info crit   = -113.025725
#     Bayesian info crit = -102.053876
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     n1:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   187.018077 (init = 188.1465)
#     n1:   0.60000339 (init = 0.600001)
#     fs1:  20291071.9 (init = 1.970999e+07)
#     n:    0.84142889 (init = 0.8390459)
#     Q:    1.0010e-07 (init = 1.018524e-07)
# None
# Start R1 value for temp 55C, replicate 9: 188.14651003840055
# Refined R1 value for temp 55C, replicate 9: 187.0180771357255
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 11
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 3.28724632
#     reduced chi-square = 0.08218116
#     Akaike info crit   = -109.375194
#     Bayesian info crit = -98.4033454
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     R1:   at initial value
#     n1:   at initial value
#     n1:   at boundary
#     fs1:  at initial value
#     n:    at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   187.018077 (init = 187.0181)
#     n1:   0.60000339 (init = 0.6000034)
#     fs1:  20291071.9 (init = 2.029107e+07)
#     n:    0.84142889 (init = 0.8414289)
#     Q:    1.0010e-07 (init = 1.00104e-07)
# None
# Start R1 value for temp 55C, replicate 10: 187.0180771357255
# Refined R1 value for temp 55C, replicate 10: 187.0180771357255
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 535
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 2.48570860
#     reduced chi-square = 0.06214272
#     Akaike info crit   = -122.231847
#     Bayesian info crit = -111.259998
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     n1:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   185.029937 (init = 187.0181)
#     n1:   0.60000202 (init = 0.6000034)
#     fs1:  21398934.8 (init = 2.029107e+07)
#     n:    0.84624221 (init = 0.8414289)
#     Q:    9.6317e-08 (init = 1.00104e-07)
# None
# Start R1 value for temp 55C, replicate 11: 187.0180771357255
# Refined R1 value for temp 55C, replicate 11: 185.0299369277053
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 151
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 2.25391586
#     reduced chi-square = 0.05634790
#     Akaike info crit   = -126.734726
#     Bayesian info crit = -115.762878
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     n1:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   183.138912 (init = 185.0299)
#     n1:   0.60000128 (init = 0.600002)
#     fs1:  21869815.2 (init = 2.139893e+07)
#     n:    0.84687541 (init = 0.8462422)
#     Q:    9.6683e-08 (init = 9.631746e-08)
# None
# Start R1 value for temp 55C, replicate 12: 185.0299369277053
# Refined R1 value for temp 55C, replicate 12: 183.13891181342967
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 1215
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.24343462
#     reduced chi-square = 0.00608587
#     Akaike info crit   = -229.111221
#     Bayesian info crit = -218.139372
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   138.569390 (init = 183.1389)
#     n1:   0.60000967 (init = 0.6000013)
#     fs1:  36022386.5 (init = 2.186982e+07)
#     n:    0.88190533 (init = 0.8468754)
#     Q:    7.4549e-08 (init = 9.668309e-08)
# None
# Start R1 value for temp 65C, replicate 1: 183.13891181342967
# Refined R1 value for temp 65C, replicate 1: 138.56939040657323
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 259
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.16183125
#     reduced chi-square = 0.00404578
#     Akaike info crit   = -247.892758
#     Bayesian info crit = -236.920910
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   141.471868 (init = 138.5694)
#     n1:   0.60001250 (init = 0.6000097)
#     fs1:  40743356.2 (init = 3.602239e+07)
#     n:    0.88362286 (init = 0.8819053)
#     Q:    7.3537e-08 (init = 7.454943e-08)
# None
# Start R1 value for temp 65C, replicate 2: 138.56939040657323
# Refined R1 value for temp 65C, replicate 2: 141.47186755408825
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 10
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 1.28979380
#     reduced chi-square = 0.03224485
#     Akaike info crit   = -152.411316
#     Bayesian info crit = -141.439467
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     R1:   at initial value
#     n1:   at initial value
#     fs1:  at initial value
#     n:    at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   141.471868 (init = 141.4719)
#     n1:   0.60001250 (init = 0.6000125)
#     fs1:  40743356.2 (init = 4.074336e+07)
#     n:    0.88362286 (init = 0.8836229)
#     Q:    7.3537e-08 (init = 7.353747e-08)
# None
# Start R1 value for temp 65C, replicate 3: 141.47186755408825
# Refined R1 value for temp 65C, replicate 3: 141.47186755408825
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 11
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 7.49679474
#     reduced chi-square = 0.18741987
#     Akaike info crit   = -71.4516284
#     Bayesian info crit = -60.4797801
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     R1:   at initial value
#     n1:   at initial value
#     fs1:  at initial value
#     n:    at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   141.471868 (init = 141.4719)
#     n1:   0.60001250 (init = 0.6000125)
#     fs1:  40743356.2 (init = 4.074336e+07)
#     n:    0.88362286 (init = 0.8836229)
#     Q:    7.3537e-08 (init = 7.353747e-08)
# None
# Start R1 value for temp 65C, replicate 4: 141.47186755408825
# Refined R1 value for temp 65C, replicate 4: 141.47186755408825
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 11
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 18.2197017
#     reduced chi-square = 0.45549254
#     Akaike info crit   = -30.6023422
#     Bayesian info crit = -19.6304939
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     R1:   at initial value
#     n1:   at initial value
#     fs1:  at initial value
#     n:    at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   141.471868 (init = 141.4719)
#     n1:   0.60001250 (init = 0.6000125)
#     fs1:  40743356.2 (init = 4.074336e+07)
#     n:    0.88362286 (init = 0.8836229)
#     Q:    7.3537e-08 (init = 7.353747e-08)
# None
# Start R1 value for temp 65C, replicate 5: 141.47186755408825
# Refined R1 value for temp 65C, replicate 5: 141.47186755408825
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 599
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.06886805
#     reduced chi-square = 0.00172170
#     Akaike info crit   = -287.193398
#     Bayesian info crit = -276.221549
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   131.762130 (init = 141.4719)
#     n1:   0.60001403 (init = 0.6000125)
#     fs1:  50499686.7 (init = 4.074336e+07)
#     n:    0.88980048 (init = 0.8836229)
#     Q:    7.1096e-08 (init = 7.353747e-08)
# None
# Start R1 value for temp 65C, replicate 6: 141.47186755408825
# Refined R1 value for temp 65C, replicate 6: 131.76212954046918
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 10
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.20119837
#     reduced chi-square = 0.00502996
#     Akaike info crit   = -237.876846
#     Bayesian info crit = -226.904998
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     R1:   at initial value
#     n1:   at initial value
#     fs1:  at initial value
#     n:    at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   131.762130 (init = 131.7621)
#     n1:   0.60001403 (init = 0.600014)
#     fs1:  50499686.7 (init = 5.049969e+07)
#     n:    0.88980048 (init = 0.8898005)
#     Q:    7.1096e-08 (init = 7.109565e-08)
# None
# Start R1 value for temp 65C, replicate 7: 131.76212954046918
# Refined R1 value for temp 65C, replicate 7: 131.76212954046918
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 10
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 1.14501109
#     reduced chi-square = 0.02862528
#     Akaike info crit   = -157.888445
#     Bayesian info crit = -146.916597
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     R1:   at initial value
#     n1:   at initial value
#     fs1:  at initial value
#     n:    at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   131.762130 (init = 131.7621)
#     n1:   0.60001403 (init = 0.600014)
#     fs1:  50499686.7 (init = 5.049969e+07)
#     n:    0.88980048 (init = 0.8898005)
#     Q:    7.1096e-08 (init = 7.109565e-08)
# None
# Start R1 value for temp 65C, replicate 8: 131.76212954046918
# Refined R1 value for temp 65C, replicate 8: 131.76212954046918
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 261
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.04754122
#     reduced chi-square = 0.00118853
#     Akaike info crit   = -304.240782
#     Bayesian info crit = -293.268934
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   124.387189 (init = 131.7621)
#     n1:   0.60001875 (init = 0.600014)
#     fs1:  52174688.5 (init = 5.049969e+07)
#     n:    0.89230804 (init = 0.8898005)
#     Q:    7.0353e-08 (init = 7.109565e-08)
# None
# Start R1 value for temp 65C, replicate 9: 131.76212954046918
# Refined R1 value for temp 65C, replicate 9: 124.38718888230227
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 10
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.10785511
#     reduced chi-square = 0.00269638
#     Akaike info crit   = -266.557963
#     Bayesian info crit = -255.586114
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     R1:   at initial value
#     n1:   at initial value
#     fs1:  at initial value
#     n:    at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   124.387189 (init = 124.3872)
#     n1:   0.60001875 (init = 0.6000187)
#     fs1:  52174688.5 (init = 5.217469e+07)
#     n:    0.89230804 (init = 0.892308)
#     Q:    7.0353e-08 (init = 7.035285e-08)
# None
# Start R1 value for temp 65C, replicate 10: 124.38718888230227
# Refined R1 value for temp 65C, replicate 10: 124.38718888230227
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 105
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.04044254
#     reduced chi-square = 0.00101106
#     Akaike info crit   = -311.679668
#     Bayesian info crit = -300.707819
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   123.562979 (init = 124.3872)
#     n1:   0.60000391 (init = 0.6000187)
#     fs1:  54885312.8 (init = 5.217469e+07)
#     n:    0.89273659 (init = 0.892308)
#     Q:    7.0666e-08 (init = 7.035285e-08)
# None
# Start R1 value for temp 65C, replicate 11: 124.38718888230227
# Refined R1 value for temp 65C, replicate 11: 123.562979292835
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 4110
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.00411526
#     reduced chi-square = 1.0288e-04
#     Akaike info crit   = -416.797975
#     Bayesian info crit = -405.826127
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   109.400951 (init = 123.563)
#     n1:   0.60008833 (init = 0.6000039)
#     fs1:  1.0912e+08 (init = 5.488531e+07)
#     n:    0.89829105 (init = 0.8927366)
#     Q:    7.1247e-08 (init = 7.06663e-08)
# None
# Start R1 value for temp 75C, replicate 1: 123.562979292835
# Refined R1 value for temp 75C, replicate 1: 109.40095052092147
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 638
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.00174222
#     reduced chi-square = 4.3556e-05
#     Akaike info crit   = -456.336855
#     Bayesian info crit = -445.365007
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   93.5746086 (init = 109.401)
#     n1:   0.60005917 (init = 0.6000883)
#     fs1:  1.2144e+08 (init = 1.091238e+08)
#     n:    0.89538643 (init = 0.8982911)
#     Q:    7.5393e-08 (init = 7.124746e-08)
# None
# Start R1 value for temp 75C, replicate 2: 109.40095052092147
# Refined R1 value for temp 75C, replicate 2: 93.57460861725286
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 10
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.15293350
#     reduced chi-square = 0.00382334
#     Akaike info crit   = -250.494100
#     Bayesian info crit = -239.522251
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     R1:   at initial value
#     n1:   at initial value
#     fs1:  at initial value
#     n:    at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   93.5746086 (init = 93.57461)
#     n1:   0.60005917 (init = 0.6000592)
#     fs1:  1.2144e+08 (init = 1.214397e+08)
#     n:    0.89538643 (init = 0.8953864)
#     Q:    7.5393e-08 (init = 7.539339e-08)
# None
# Start R1 value for temp 75C, replicate 3: 93.57460861725286
# Refined R1 value for temp 75C, replicate 3: 93.57460861725286
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 758
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.00235316
#     reduced chi-square = 5.8829e-05
#     Akaike info crit   = -442.509272
#     Bayesian info crit = -431.537423
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   93.0777450 (init = 93.57461)
#     n1:   0.60005588 (init = 0.6000592)
#     fs1:  1.2084e+08 (init = 1.214397e+08)
#     n:    0.89735779 (init = 0.8953864)
#     Q:    7.4897e-08 (init = 7.539339e-08)
# None
# Start R1 value for temp 75C, replicate 4: 93.57460861725286
# Refined R1 value for temp 75C, replicate 4: 93.07774495592724
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 155
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.00185387
#     reduced chi-square = 4.6347e-05
#     Akaike info crit   = -453.479589
#     Bayesian info crit = -442.507741
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   91.8171605 (init = 93.07774)
#     n1:   0.60003743 (init = 0.6000559)
#     fs1:  1.2900e+08 (init = 1.208356e+08)
#     n:    0.89791937 (init = 0.8973578)
#     Q:    7.5013e-08 (init = 7.489661e-08)
# None
# Start R1 value for temp 75C, replicate 5: 93.07774495592724
# Refined R1 value for temp 75C, replicate 5: 91.81716054129652
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 10
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.04810253
#     reduced chi-square = 0.00120256
#     Akaike info crit   = -303.700844
#     Bayesian info crit = -292.728996
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     R1:   at initial value
#     n1:   at initial value
#     fs1:  at initial value
#     n:    at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   91.8171605 (init = 91.81716)
#     n1:   0.60003743 (init = 0.6000374)
#     fs1:  1.2900e+08 (init = 1.290016e+08)
#     n:    0.89791937 (init = 0.8979194)
#     Q:    7.5013e-08 (init = 7.501343e-08)
# None
# Start R1 value for temp 75C, replicate 6: 91.81716054129652
# Refined R1 value for temp 75C, replicate 6: 91.81716054129652
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 174
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.00107936
#     reduced chi-square = 2.6984e-05
#     Akaike info crit   = -478.361329
#     Bayesian info crit = -467.389480
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   88.3634826 (init = 91.81716)
#     n1:   0.60000305 (init = 0.6000374)
#     fs1:  1.4506e+08 (init = 1.290016e+08)
#     n:    0.89808680 (init = 0.8979194)
#     Q:    7.6364e-08 (init = 7.501343e-08)
# None
# Start R1 value for temp 75C, replicate 7: 91.81716054129652
# Refined R1 value for temp 75C, replicate 7: 88.36348264207317
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 238
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 9.9049e-04
#     reduced chi-square = 2.4762e-05
#     Akaike info crit   = -482.314007
#     Bayesian info crit = -471.342159
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   87.9181000 (init = 88.36348)
#     n1:   0.60000739 (init = 0.6000031)
#     fs1:  1.5835e+08 (init = 1.450616e+08)
#     n:    0.89762763 (init = 0.8980868)
#     Q:    7.7322e-08 (init = 7.636393e-08)
# None
# Start R1 value for temp 75C, replicate 8: 88.36348264207317
# Refined R1 value for temp 75C, replicate 8: 87.91810002239941
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 11
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.00407269
#     reduced chi-square = 1.0182e-04
#     Akaike info crit   = -417.276274
#     Bayesian info crit = -406.304425
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     R1:   at initial value
#     n1:   at initial value
#     fs1:  at initial value
#     n:    at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   87.9181000 (init = 87.9181)
#     n1:   0.60000739 (init = 0.6000074)
#     fs1:  1.5835e+08 (init = 1.583464e+08)
# ...
#     # variables        = 6
#     chi-square         = 2.8324e-05
#     reduced chi-square = 7.0809e-07
#     Akaike info crit   = -645.821131
#     Bayesian info crit = -634.849283
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   68.2147666 (init = 66.44196)
#     n1:   0.63689556 (init = 0.6171162)
#     fs1:  8.9584e+08 (init = 8.983013e+08)
#     n:    0.88804251 (init = 0.88943)
#     Q:    1.0331e-07 (init = 9.973871e-08)
# None
# Start R1 value for temp 85C, replicate 7: 66.44196415273029
# Refined R1 value for temp 85C, replicate 7: 68.2147666131172
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 102
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 3.5247e-05
#     reduced chi-square = 8.8116e-07
#     Akaike info crit   = -635.762100
#     Bayesian info crit = -624.790252
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   66.6420852 (init = 68.21477)
#     n1:   0.64623126 (init = 0.6368956)
#     fs1:  8.9040e+08 (init = 8.958357e+08)
#     n:    0.88690211 (init = 0.8880425)
#     Q:    1.0604e-07 (init = 1.033127e-07)
# None
# Start R1 value for temp 85C, replicate 8: 68.2147666131172
# Refined R1 value for temp 85C, replicate 8: 66.64208518358805
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 95
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 4.8823e-05
#     reduced chi-square = 1.2206e-06
#     Akaike info crit   = -620.773603
#     Bayesian info crit = -609.801755
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   65.1315490 (init = 66.64209)
#     n1:   0.67422173 (init = 0.6462313)
#     fs1:  8.7074e+08 (init = 8.903969e+08)
#     n:    0.88521770 (init = 0.8869021)
#     Q:    1.0954e-07 (init = 1.060424e-07)
# None
# Start R1 value for temp 85C, replicate 9: 66.64208518358805
# Refined R1 value for temp 85C, replicate 9: 65.1315490429738
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 24
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 1.9681e-04
#     reduced chi-square = 4.9204e-06
#     Akaike info crit   = -556.647070
#     Bayesian info crit = -545.675222
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   65.0277870 (init = 65.13155)
#     n1:   0.60013922 (init = 0.6742217)
#     fs1:  8.7877e+08 (init = 8.707419e+08)
#     n:    0.88683924 (init = 0.8852177)
#     Q:    1.0836e-07 (init = 1.095402e-07)
# None
# Start R1 value for temp 85C, replicate 10: 65.1315490429738
# Refined R1 value for temp 85C, replicate 10: 65.02778704398082
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 353
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 3.9762e-05
#     reduced chi-square = 9.9404e-07
#     Akaike info crit   = -630.217600
#     Bayesian info crit = -619.245752
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   64.9320336 (init = 65.02779)
#     n1:   0.92683822 (init = 0.6001392)
#     fs1:  2.2021e+08 (init = 8.787722e+08)
#     n:    0.88347667 (init = 0.8868392)
#     Q:    1.1391e-07 (init = 1.083578e-07)
# None
# Start R1 value for temp 85C, replicate 11: 65.02778704398082
# Refined R1 value for temp 85C, replicate 11: 64.93203363877598
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 185
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 6.7817e-05
#     reduced chi-square = 1.6954e-06
#     Akaike info crit   = -605.657524
#     Bayesian info crit = -594.685676
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   64.5017290 (init = 64.93203)
#     n1:   0.77811016 (init = 0.9268382)
#     fs1:  5.6000e+08 (init = 2.202119e+08)
#     n:    0.88234875 (init = 0.8834767)
#     Q:    1.1642e-07 (init = 1.139125e-07)
# None
# Start R1 value for temp 85C, replicate 12: 64.93203363877598
# Refined R1 value for temp 85C, replicate 12: 64.50172895799966
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 97
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 9.7441e-05
#     reduced chi-square = 2.4360e-06
#     Akaike info crit   = -588.985505
#     Bayesian info crit = -578.013657
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   61.4856338 (init = 64.50173)
#     n1:   0.97563979 (init = 0.7781102)
#     fs1:  3.1016e+08 (init = 5.600011e+08)
#     n:    0.87718182 (init = 0.8823487)
#     Q:    1.2938e-07 (init = 1.164187e-07)
# None
# Start R1 value for temp 95C, replicate 1: 64.50172895799966
# Refined R1 value for temp 95C, replicate 1: 61.485633806590556
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 117
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 1.3647e-04
#     reduced chi-square = 3.4118e-06
#     Akaike info crit   = -573.489276
#     Bayesian info crit = -562.517427
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   61.1762047 (init = 61.48563)
#     n1:   0.99605320 (init = 0.9756398)
#     fs1:  3.2539e+08 (init = 3.101639e+08)
#     n:    0.87637622 (init = 0.8771818)
#     Q:    1.3149e-07 (init = 1.293807e-07)
# None
# Start R1 value for temp 95C, replicate 2: 61.485633806590556
# Refined R1 value for temp 95C, replicate 2: 61.1762046576203
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 125
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 2.0107e-04
#     reduced chi-square = 5.0266e-06
#     Akaike info crit   = -555.663950
#     Bayesian info crit = -544.692102
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   53.8938744 (init = 61.1762)
#     n1:   0.89984889 (init = 0.9960532)
#     fs1:  8.9944e+08 (init = 3.253864e+08)
#     n:    0.87344248 (init = 0.8763762)
#     Q:    1.3777e-07 (init = 1.314871e-07)
# None
# Start R1 value for temp 95C, replicate 3: 61.1762046576203
# Refined R1 value for temp 95C, replicate 3: 53.89387436327553
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 102
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 2.7503e-04
#     reduced chi-square = 6.8759e-06
#     Akaike info crit   = -541.253666
#     Bayesian info crit = -530.281818
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   47.2919565 (init = 53.89387)
#     n1:   0.99993610 (init = 0.8998489)
#     fs1:  8.9925e+08 (init = 8.994387e+08)
#     n:    0.86923966 (init = 0.8734425)
#     Q:    1.4999e-07 (init = 1.37768e-07)
# None
# Start R1 value for temp 95C, replicate 4: 53.89387436327553
# Refined R1 value for temp 95C, replicate 4: 47.29195646202555
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 117
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 5.2841e-04
#     reduced chi-square = 1.3210e-05
#     Akaike info crit   = -511.216751
#     Bayesian info crit = -500.244903
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   44.1760450 (init = 47.29196)
#     n1:   0.99986774 (init = 0.9999361)
#     fs1:  8.9764e+08 (init = 8.992508e+08)
#     n:    0.86527860 (init = 0.8692397)
#     Q:    1.6358e-07 (init = 1.499925e-07)
# None
# Start R1 value for temp 95C, replicate 5: 47.29195646202555
# Refined R1 value for temp 95C, replicate 5: 44.17604504425299
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 413
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 6.4655e-04
#     reduced chi-square = 1.6164e-05
#     Akaike info crit   = -501.935011
#     Bayesian info crit = -490.963163
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   43.8748249 (init = 44.17605)
#     n1:   0.99998066 (init = 0.9998677)
#     fs1:  8.9999e+08 (init = 8.976409e+08)
#     n:    0.86255346 (init = 0.8652786)
#     Q:    1.7275e-07 (init = 1.635807e-07)
# None
# Start R1 value for temp 95C, replicate 6: 44.17604504425299
# Refined R1 value for temp 95C, replicate 6: 43.87482488432681
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 9
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.01053237
#     reduced chi-square = 2.6331e-04
#     Akaike info crit   = -373.569378
#     Bayesian info crit = -362.597530
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     R1:   at initial value
#     n1:   at initial value
#     fs1:  at initial value
#     n:    at initial value
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   43.8748249 (init = 43.87482)
#     n1:   0.99998066 (init = 0.9999807)
#     fs1:  8.9999e+08 (init = 8.99988e+08)
#     n:    0.86255346 (init = 0.8625535)
#     Q:    1.7275e-07 (init = 1.727494e-07)
# None
# Start R1 value for temp 95C, replicate 7: 43.87482488432681
# Refined R1 value for temp 95C, replicate 7: 43.87482488432681
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 3545
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 8.8326e-04
#     reduced chi-square = 2.2082e-05
#     Akaike info crit   = -487.584420
#     Bayesian info crit = -476.612572
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     fs1:  at boundary
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   44.4399811 (init = 43.87482)
#     n1:   0.99959034 (init = 0.9999807)
#     fs1:  9.0000e+08 (init = 8.99988e+08)
#     n:    0.85969143 (init = 0.8625535)
#     Q:    1.8395e-07 (init = 1.727494e-07)
# None
# Start R1 value for temp 95C, replicate 8: 43.87482488432681
# Refined R1 value for temp 95C, replicate 8: 44.43998113945469
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 407
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 9.7950e-04
#     reduced chi-square = 2.4487e-05
#     Akaike info crit   = -482.827133
#     Bayesian info crit = -471.855285
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     fs1:  at initial value
#     fs1:  at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   44.0261355 (init = 44.43998)
#     n1:   0.99992329 (init = 0.9995903)
#     fs1:  9.0000e+08 (init = 9e+08)
#     n:    0.85708311 (init = 0.8596914)
#     Q:    1.9277e-07 (init = 1.839541e-07)
# None
# Start R1 value for temp 95C, replicate 9: 44.43998113945469
# Refined R1 value for temp 95C, replicate 9: 44.02613551501844
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 1217
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.00126142
#     reduced chi-square = 3.1536e-05
#     Akaike info crit   = -471.191182
#     Bayesian info crit = -460.219334
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   44.0190534 (init = 44.02614)
#     n1:   1.00000000 (init = 0.9999233)
#     fs1:  8.9541e+08 (init = 8.999964e+08)
#     n:    0.85665209 (init = 0.8570831)
#     Q:    1.9615e-07 (init = 1.927725e-07)
# None
# Start R1 value for temp 95C, replicate 10: 44.02613551501844
# Refined R1 value for temp 95C, replicate 10: 44.019053402344355
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 481
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.00118983
#     reduced chi-square = 2.9746e-05
#     Akaike info crit   = -473.879128
#     Bayesian info crit = -462.907280
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     n1:   at initial value
#     n1:   at boundary
#     fs1:  at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   43.8204767 (init = 44.01905)
#     n1:   0.99999329 (init = 1)
#     fs1:  9.0000e+08 (init = 8.954145e+08)
#     n:    0.85384164 (init = 0.8566521)
#     Q:    2.0549e-07 (init = 1.961526e-07)
# None
# Start R1 value for temp 95C, replicate 11: 44.019053402344355
# Refined R1 value for temp 95C, replicate 11: 43.82047669171385
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 17
#     # data points      = 46
#     # variables        = 6
#     chi-square         = 0.00267241
#     reduced chi-square = 6.6810e-05
#     Akaike info crit   = -436.657153
#     Bayesian info crit = -425.685304
# ##  Warning: uncertainties could not be estimated:
#     Rs:   at boundary
#     Q:    at initial value
# [[Variables]]
#     Rs:   0.00000000 (init = 0)
#     R1:   43.6992764 (init = 43.82048)
#     n1:   0.79758011 (init = 0.9999933)
#     fs1:  8.9821e+08 (init = 9e+08)
#     n:    0.85375673 (init = 0.8538416)
#     Q:    2.0677e-07 (init = 2.054948e-07)
# None
# Start R1 value for temp 95C, replicate 12: 43.82047669171385
# Refined R1 value for temp 95C, replicate 12: 43.69927641967308
# {(30, 1): {(30, 1): None}, (30, 2): {(30, 2): None}, (30, 3): {(30, 3): None}, (30, 4): {(30, 4): None}, (30, 5): {(30, 5): None}, (30, 6): {(30, 6): None}, (30, 7): {(30, 7): None}, (35, 1): {(35, 1): None}, (35, 2): {(35, 2): None}, (35, 3): {(35, 3): None}, (35, 4): {(35, 4): None}, (35, 5): {(35, 5): None}, (35, 6): {(35, 6): None}, (35, 7): {(35, 7): None}, (35, 8): {(35, 8): None}, (35, 9): {(35, 9): None}, (45, 1): {(45, 1): None}, (45, 2): {(45, 2): None}, (45, 3): {(45, 3): None}, (45, 4): {(45, 4): None}, (45, 5): {(45, 5): None}, (45, 6): {(45, 6): None}, (45, 7): {(45, 7): None}, (45, 8): {(45, 8): None}, (45, 9): {(45, 9): None}, (45, 10): {(45, 10): None}, (45, 11): {(45, 11): None}, (55, 1): {(55, 1): None}, (55, 2): {(55, 2): None}, (55, 3): {(55, 3): None}, (55, 4): {(55, 4): None}, (55, 5): {(55, 5): None}, (55, 6): {(55, 6): None}, (55, 7): {(55, 7): None}, (55, 8): {(55, 8): None}, (55, 9): {(55, 9): None}, (55, 10): {(55, 10): None}, (55, 11): {(55, 11): None}, (55, 12): {(55, 12): None}, (65, 1): {(65, 1): None}, (65, 2): {(65, 2): None}, (65, 3): {(65, 3): None}, (65, 4): {(65, 4): None}, (65, 5): {(65, 5): None}, (65, 6): {(65, 6): None}, (65, 7): {(65, 7): None}, (65, 8): {(65, 8): None}, (65, 9): {(65, 9): None}, (65, 10): {(65, 10): None}, (65, 11): {(65, 11): None}, (75, 1): {(75, 1): None}, (75, 2): {(75, 2): None}, (75, 3): {(75, 3): None}, (75, 4): {(75, 4): None}, (75, 5): {(75, 5): None}, (75, 6): {(75, 6): None}, (75, 7): {(75, 7): None}, (75, 8): {(75, 8): None}, (75, 9): {(75, 9): None}, (75, 10): {(75, 10): None}, (75, 11): {(75, 11): None}, (75, 12): {(75, 12): None}, (85, 1): {(85, 1): None}, (85, 2): {(85, 2): None}, (85, 3): {(85, 3): None}, (85, 4): {(85, 4): None}, (85, 5): {(85, 5): None}, (85, 6): {(85, 6): None}, (85, 7): {(85, 7): None}, (85, 8): {(85, 8): None}, (85, 9): {(85, 9): None}, (85, 10): {(85, 10): None}, (85, 11): {(85, 11): None}, (85, 12): {(85, 12): None}, (95, 1): {(95, 1): None}, (95, 2): {(95, 2): None}, (95, 3): {(95, 3): None}, (95, 4): {(95, 4): None}, (95, 5): {(95, 5): None}, (95, 6): {(95, 6): None}, (95, 7): {(95, 7): None}, (95, 8): {(95, 8): None}, (95, 9): {(95, 9): None}, (95, 10): {(95, 10): None}, (95, 11): {(95, 11): None}, (95, 12): {(95, 12): None}}

# %%
#plot individual data with fitting
#The below example plots all of the replicates at 30C
plt.figure(figsize=(6,6))
for key, exp_instance in all_experiments.items():
    if key[0]==30:
        all_experiments[key].EIS_plot(fitting='on')
    
#all_experiments[30]['Ex7_Temp30'].EIS_plot(fitting='on')
#xdownlim=0
#uplim=40000
#plt.ylim(0,uplim)
#plt.xlim(xdownlim,uplim)

plt.show()

# %%
#Here we load in the optimized values for R1 and the characteristic frequency into discrete dictionaries

R1_opt = {}
Fs1_opt={}
# Iterate through the outer dictionary (temperature-wise experiments)
for key, exp_instance in all_experiments.items():
    # Iterate through the inner dictionary (individual experiments for each temperature)
    sim_temp= cir_RsRQQ(w=f_range[1], Rs=float(exp_instance.fit_Rs[0]), R1=float(exp_instance.fit_R1[0]), n1=float(exp_instance.fit_n1[0]), Q1=((1/(2*3.14159*float(exp_instance.fit_fs1[0])))**float(exp_instance.fit_n1[0]))/float(exp_instance.fit_R1[0]), n=float(exp_instance.fit_n[0]), Q=float(exp_instance.fit_Q[0]))
    sim[exp_name]=sim_temp

nyquist={}
# Iterate through the outer dictionary (temperature-wise experiments)
for exp_name, exp_instance in all_experiments.items():
     # Find the minimum length among the arrays for this experiment
    min_length = min(len(exp_instance.df_raw.re), len(exp_instance.df_raw.im), len(sim[exp_name].real), len(sim[exp_name].imag),len(exp_instance.df_raw.f))
    exp_name_temp=[exp_name]*min_length
    #samplenamez=[samplename]*min_length
    #materialnamez=[materialname]*min_length
    # Truncate arrays to the minimum length
    truncated_re = exp_instance.df_raw.re[:min_length]
    truncated_im = exp_instance.df_raw.im[:min_length]
    truncated_f= exp_instance.df_raw.f[:min_length]
    truncated_fit_real = sim[exp_name].real[:min_length]
    truncated_fit_imag = -sim[exp_name].imag[:min_length]
    
    # Create DataFrame with truncated arrays
    nyquist[exp_name] = pd.DataFrame({
        'Frequency':truncated_f,
        'Z real': truncated_re,
        'Z imag': truncated_im,
        'Fit real': truncated_fit_real,
        'Fit imag': truncated_fit_imag,
        'Dataset':exp_name_temp,
        #'sample_name':samplenamez,
        #'material_name':materialnamez
    })
    print(nyquist[exp_name])
# Out:
# [2000000.         1583363.8318526  1253520.51200948  992389.52060058]
#
# [12566370.61435917  9948568.36421585  7876101.66330618  6235367.25483656]
#        Frequency        Z real        Z imag      Fit real      Fit imag  \
# 0   2.000039e+06  4.388329e+02  1.059872e+02  4.320029e+02  9.399398e+01
# 1   1.588711e+06  4.490392e+02  1.064651e+02  4.388205e+02  9.827369e+01
# 2   1.261992e+06  4.577422e+02  1.086529e+02  4.463108e+02  1.057424e+02
# 3   1.002539e+06  4.660350e+02  1.141770e+02  4.547766e+02  1.164602e+02
# 4   7.962891e+05  4.743600e+02  1.232659e+02  4.645041e+02  1.305895e+02
# ..           ...           ...           ...           ...           ...
# 65  6.334459e-01  2.082415e+06  7.312345e+06  1.069915e+06  1.958970e+06
# 66  5.029507e-01  2.613363e+06  8.841039e+06  1.254583e+06  2.297217e+06
# 67  3.999573e-01  3.274189e+06  1.066132e+07  1.471138e+06  2.693867e+06
# 68  3.175813e-01  4.106917e+06  1.285212e+07  1.725083e+06  3.159005e+06
# 69  2.520161e-01  5.150574e+06  1.547812e+07  2.022876e+06  3.704455e+06
#
#     Dataset
# 0   (30, 1)
# 1   (30, 1)
# 2   (30, 1)
# 3   (30, 1)
# 4   (30, 1)
# ..      ...
# 65  (30, 1)
# 66  (30, 1)
# 67  (30, 1)
# 68  (30, 1)
# 69  (30, 1)
#
# [70 rows x 6 columns]
#        Frequency        Z real        Z imag      Fit real      Fit imag  \
# 0   2.000039e+06  4.380103e+02  1.041267e+02  4.310554e+02  9.274622e+01
# 1   1.588711e+06  4.474262e+02  1.051756e+02  4.377936e+02  9.702790e+01
# 2   1.261992e+06  4.560897e+02  1.080544e+02  4.452078e+02  1.044487e+02
# 3   1.002539e+06  4.645946e+02  1.128996e+02  4.535940e+02  1.150682e+02
# 4   7.962891e+05  4.725270e+02  1.216609e+02  4.632335e+02  1.290472e+02
# ..           ...           ...           ...           ...           ...
# 65  6.334459e-01  1
# 66  (95, 10)
# 67  (95, 10)
# 68  (95, 10)
# 69  (95, 10)
#
# [70 rows x 6 columns]
#        Frequency        Z real         Z imag       Fit real      Fit imag  \
# 0   2.000039e+06      45.21187       3.653008      44.781251  4.209358e+00
# 1   1.588711e+06      45.30653       4.602486      44.993457  5.096731e+00
# 2   1.261992e+06      45.43968       5.759706      45.252457  6.188683e+00
# 3   1.002539e+06      45.77302       6.959598      45.568597  7.528558e+00
# 4   7.962891e+05      46.11562       8.562187      45.954501  9.169647e+00
# ..           ...           ...            ...            ...           ...
# 65  6.334459e-01  225311.30000  325705.200000  410365.803086  1.755721e+06
# 66  5.029507e-01  261509.80000  374498.800000  500938.478655  2.143271e+06
# 67  3.999573e-01  303412.50000  429659.800000  611503.769554  2.616368e+06
# 68  3.175813e-01  352653.10000  492872.700000  746474.758043  3.193893e+06
# 69  2.520161e-01  410302.20000  564545.500000  911238.650811  3.898899e+06
#
#      Dataset
# 0   (95, 11)
# 1   (95, 11)
# 2   (95, 11)
# 3   (95, 11)
# 4   (95, 11)
# ..       ...
# 65  (95, 11)
# 66  (95, 11)
# 67  (95, 11)
# 68  (95, 11)
# 69  (95, 11)
#
# [70 rows x 6 columns]
#        Frequency        Z real         Z imag       Fit real      Fit imag  \
# 0   2.000039e+06      45.16637       3.522302      44.549463  4.408912e+00
# 1   1.588711e+06      45.26933       4.556218      44.779112  5.258513e+00
# 2   1.261992e+06      45.38808       5.731219      45.052156  6.316507e+00
# 3   1.002539e+06      45.68792       6.893018      45.379457  7.625376e+00
# 4   7.962891e+05      46.01898       8.469259      45.774045  9.237565e+00
# ..           ...           ...            ...            ...           ...
# 65  6.334459e-01  219773.20000  318667.900000  408117.821487  1.745052e+06
# 66  5.029507e-01  255198.80000  366473.300000  498184.433775  2.130205e+06
# 67  3.999573e-01  296234.20000  420587.400000  608129.774480  2.600366e+06
# 68  3.175813e-01  344494.00000  482439.900000  742341.305651  3.174297e+06
# 69  2.520161e-01  401019.80000  552669.200000  906174.852248  3.874900e+06
#
#      Dataset
# 0   (95, 12)
# 1   (95, 12)
# 2   (95, 12)
# 3   (95, 12)
# 4   (95, 12)
# ..       ...
# 65  (95, 12)
# 66  (95, 12)
# 67  (95, 12)
# 68  (95, 12)
# 69  (95, 12)
#
# [70 rows x 6 columns]

# %%
#Define functions

#function to generate a list of files from the target directory
def file_dict(file_DIR):
    ext = ('*.csv')
    list_files = glob.glob(os.path.join(file_DIR, ext))
    return list_files

#function to generate a list of colors in hex format using start color, end color, and the target folder(directory) length
def color_gradient(startcolor,endcolor,temperatures):
    color_list = list(startcolor.range_to(endcolor, len(temperatures)))
    datacolor = {}
    for temp, color in zip(sorted(temperatures), color_list):
        datacolor[temp] = color.hex
    return datacolor

#This is a function whose only purpose is to extract the replicate number from the dataset name
def extract_temp_replicate(string):
    temp_match = re.search(r'temp_(\d+)_', string)
    if temp_match:
        temp_match=int(temp_match.group(1))
    else:
        return None
    replicate_match=re.search(r'replicate_(\d+)_', string)
    if replicate_match:
        replicate_match=int(replicate_match.group(1))
    else:
        return None
    return temp_match, replicate_match

#generate a marker for each temperature
def make_markers(marker_types,unique_temperatures):
    markers={}
    markers=marker_types * (len(unique_temperatures) // len(marker_types)) + marker_types[:len(unique_temperatures) % len(marker_types)]
    tempmarkers={}
    for i, temp in enumerate(sorted(unique_temperatures)):
        marker_index = i % len(markers)  # Calculate marker index based on the position of temperature
        tempmarkers[temp] = markers[marker_index]
    return tempmarkers

# Define a function to format the axis multiplier
def format_axis(value, tick_number, limit):
    if limit >= 1e9:
        value = value / 1e9
    elif limit >= 1e6:
        value = value / 1e6
    elif limit >= 3e3:
        value = value / 1e3
    return '{:.0f}'.format(value)

# Define a function to format the axis label unit
def labelprefix(limit):
    prefix = ''
    if limit >= 1e9:
        prefix = 'G'
    elif limit >= 1e6:
        prefix = 'M'
    elif limit >= 3e3:
        prefix = 'k'
    return prefix

#goes to the first csf and grabs the first entry in the material name column
def getmaterialname(filelist):
    firstdataframe=pd.read_csv(filelist[0])
    materialname=firstdataframe.at[0,'material_name']
    return materialname

#goes to the first csf and grabs the first entry in the sample name column
def getsamplename(filelist):
    firstdataframe=pd.read_csv(filelist[0])
    samplename=firstdataframe.at[0,'sample_name']
    return samplename

# %%
#This cell generates temperature dependent nyquist plots and tracks the variance between the maximum and minimum R1 values
#This is so you can see whether there is systematic drift due to equilibriation

from collections import defaultdict
import math
import matplotlib.colors as mcolors
from matplotlib.pyplot import rc

rc('text',usetex=True)
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']},size='16')
rc('text.latex', preamble=r'\usepackage{sfmath}')
# Create a colormap

cmap = mcolors.LinearSegmentedColormap.from_list("gradient", ["#3399ff", "#ff66ff"])

# Normalize the key[1] values
all_keys = [key[1] for key in nyquist.keys()]
norm = mcolors.Normalize(vmin=min(all_keys), vmax=max(all_keys))

# Group the DataFrames by the first element of their keys
grouped_nyquist = defaultdict(list)
for key, df in nyquist.items():
    grouped_nyquist[key[0]].append((key, df))

# Sort dataframes in each group by key[1]
for group_key in grouped_nyquist:
    grouped_nyquist[group_key].sort(key=lambda x: x[0][1])

# Create subplots in a 2-column layout
num_plots = len(grouped_nyquist)
num_cols = 2
num_rows = math.ceil(num_plots / num_cols)
figsize = (12, 6 * num_rows)
fig0, axes = plt.subplots(num_rows, num_cols, figsize=figsize)
axes = axes.flatten()

# Store variance results
variance_results = {}

# Loop through each group and plot
for ax, (group_key, dataframes) in zip(axes, grouped_nyquist.items()):
    z_real_at_min_z_imag = {}
    
    for i, (key, df) in enumerate(dataframes):
        if i == len(dataframes) - 1:
            color = "#ff66ff"
        else:
            color = cmap(norm(key[1]))
        ax.plot(df['Z real'], df['Z imag'], linestyle='none', marker='o', color=color)
        
        # Find index of minimum value in 'Z imag'
        min_index = df['Z imag'].idxmin()
        z_real_at_min_z_imag[key] = df.loc[min_index, 'Z real']
    
    # Calculate percent variance
    var = ((max(z_real_at_min_z_imag.values()) - min(z_real_at_min_z_imag.values())) / min(z_real_at_min_z_imag.values()))*100
    variance_results[group_key] = var
    
    # Annotate variance on plot
    ax.annotate(f'Variance: {var:.2f}\%', xy=(0.1, 0.9), xycoords='axes fraction', ha='left', fontsize=14, bbox=dict(boxstyle="round,pad=0.3", edgecolor='black', facecolor='white'))
    
    # Set limits for each subplot
    max_value = max(z_real_at_min_z_imag.values())
    limit = max_value * 1.5
    ax.set(xlim=(0, limit), ylim=(0, limit))
    ax.set_xlabel('Z$_{real}$ [$\Omega$]')
    ax.set_ylabel('-Z$_{imag}$ [$\Omega$]')
    ax.set_title(f'{group_key} $^\circ$C')

# Hide any unused axes
for i in range(len(grouped_nyquist), len(axes)):
    fig0.delaxes(axes[i])

fig0.suptitle(materialname, y=1)
plt.tight_layout()
plt.show()

# %%
#This cell yeets out datasets starting at the first one collected until the variance falls below a user defined value

from collections import defaultdict
import math
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Define `nyquist`, `R1_opt`, `Fs1_opt`, `all_experiments`, and `variance_results` (sample structure)

variance_results = {}
filtered_nyquist = {}
filtered_R1_opt = {}
filtered_Fs1_opt = {}
filtered_all_experiments = {}

# Check if variables are dictionaries
if not isinstance(nyquist, dict):
    raise TypeError("nyquist must be a dictionary")
if not isinstance(R1_opt, dict):
    raise TypeError("R1_opt must be a dictionary")
if not isinstance(Fs1_opt, dict):
    raise TypeError("Fs1_opt must be a dictionary")
if not isinstance(all_experiments, dict):
    raise TypeError("all_experiments must be a dictionary")

# Create a colormap
cmap = mcolors.LinearSegmentedColormap.from_list("gradient", ["#3399ff", "#ff66ff"])

# Normalize the key[1] values if nyquist is not empty
if nyquist:
    all_keys = [key[1] for key in nyquist.keys()]
    norm = mcolors.Normalize(vmin=min(all_keys), vmax=max(all_keys))

# Group the DataFrames by the first element of their keys
grouped_nyquist = defaultdict(list)
for key, df in nyquist.items():
    grouped_nyquist[key[0]].append((key, df))

# Sort dataframes in each group by key[1]
for group_key in grouped_nyquist:
    grouped_nyquist[group_key].sort(key=lambda x: x[0][1])

# Create subplots in a 2-column layout
num_plots = len(grouped_nyquist)
num_cols = 2
num_rows = math.ceil(num_plots / num_cols)
figsize = (12, 6 * num_rows)
fig0, axes = plt.subplots(num_rows, num_cols, figsize=figsize)
axes = axes.flatten()

# Function to calculate variance
def calculate_variance(z_real_values):
    return ((max(z_real_values) - min(z_real_values)) / min(z_real_values)) * 100

# User-defined variance threshold
#Change this value as needed
variance_threshold = 2  # Example threshold, modify as needed

# Loop through each group and plot
for ax, (group_key, dataframes) in zip(axes, grouped_nyquist.items()):
    z_real_at_min_z_imag = {}
    filtered_dataframes = dataframes[:]
    original_count = len(dataframes)
    
    # Filter dataframes until variance is below threshold
    while True:
        for i, (key, df) in enumerate(filtered_dataframes):
            # Find index of minimum value in 'Z imag'
            min_index = df['Z imag'].idxmin()
            z_real_at_min_z_imag[key] = df.loc[min_index, 'Z real']
        
        # Calculate percent variance
        var = calculate_variance(list(z_real_at_min_z_imag.values()))
        
        # Break the loop if variance is below threshold or only one dataframe is left
        if var <= variance_threshold or len(filtered_dataframes) == 1:
            break
        
        # Remove the dataframe with the lowest key[1]
        filtered_dataframes.pop(0)
        z_real_at_min_z_imag.clear()
    
    # Store variance results
    variance_results[group_key] = var
    
    # Store filtered nyquist datasets
    for key, df in filtered_dataframes:
        filtered_nyquist[key] = df
    
    # Filter other datasets based on the keys of filtered nyquist datasets
    filtered_keys = set(filtered_nyquist.keys())
    try:
        filtered_R1_opt = {key: value for key, value in R1_opt.items() if key in filtered_keys}
        filtered_Fs1_opt = {key: value for key, value in Fs1_opt.items() if key in filtered_keys}
        filtered_all_experiments = {key: value for key, value in all_experiments.items() if key in filtered_keys}
    except AttributeError as e:
        print(f"Error while filtering: {e}")
        print(f"R1_opt type: {type(R1_opt)}")
        print(f"Fs1_opt type: {type(Fs1_opt)}")
        print(f"all_experiments type: {type(all_experiments)}")
        raise

    # Plot the filtered dataframes
    for i, (key, df) in enumerate(filtered_dataframes):
        color = cmap(norm(key[1])) if i < len(filtered_dataframes) - 1 else "#ff66ff"
        ax.plot(df['Z real'], df['Z imag'], linestyle='none', marker='o', color=color)
    
    # Annotate variance, initial count, and exclusion count on plot
    num_excluded = original_count - len(filtered_dataframes)
    ax.annotate(f'Initial Replicates: {original_count}\nExcluded Replicates: {num_excluded}\nPercent Excluded: {(num_excluded/original_count)*100:.2f}\%\nVariance: {var:.2f}\%\nVariance Threshold: {variance_threshold:.2f}\%', 
                xy=(0.1, 0.7), xycoords='axes fraction', ha='left', fontsize=14, 
                bbox=dict(boxstyle="round,pad=0.3", edgecolor='black', facecolor='white'))
    
    # Set limits for each subplot
    if z_real_at_min_z_imag:
        max_value = max(z_real_at_min_z_imag.values())
        limit = max_value * 1.5
        ax.set(xlim=(0, limit), ylim=(0, limit))
        ax.set_xlabel(f'Z$_{{real}}$ [$\Omega$]')
        ax.set_ylabel(f'-Z$_{{imag}}$ [$\Omega$]')
    ax.set_title(f'{group_key} $^\circ$C')

# Hide any unused axes
for i in range(len(grouped_nyquist), len(axes)):
    fig0.delaxes(axes[i])

fig0.suptitle(materialname, y=1)
plt.tight_layout()
plt.show()

# %%
#This cell eliminates all but the last three datasets at each temperature and reports the variance.

from collections import defaultdict
import math
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# Define `nyquist`, `R1_opt`, `Fs1_opt`, `all_experiments`, and `variance_results` (sample structure)

variance_results = {}
truncated_nyquist = {}
truncated_R1_opt = {}
truncated_Fs1_opt = {}
truncated_all_experiments = {}

# Check if variables are dictionaries
if not isinstance(nyquist, dict):
    raise TypeError("nyquist must be a dictionary")
if not isinstance(R1_opt, dict):
    raise TypeError("R1_opt must be a dictionary")
if not isinstance(Fs1_opt, dict):
    raise TypeError("Fs1_opt must be a dictionary")
if not isinstance(all_experiments, dict):
    raise TypeError("all_experiments must be a dictionary")

# Create a colormap
cmap = mcolors.LinearSegmentedColormap.from_list("gradient", ["#3399ff", "#ff66ff"])

# Normalize the key[1] values if nyquist is not empty
if nyquist:
    all_keys = [key[1] for key in nyquist.keys()]
    norm = mcolors.Normalize(vmin=min(all_keys), vmax=max(all_keys))

# Group the DataFrames by the first element of their keys
grouped_nyquist = defaultdict(list)
for key, df in nyquist.items():
    grouped_nyquist[key[0]].append((key, df))

# Keep only the last three data sets for each group
for group_key in grouped_nyquist:
    grouped_nyquist[group_key].sort(key=lambda x: x[0][1], reverse=True)
    grouped_nyquist[group_key] = grouped_nyquist[group_key][:3]

# Create subplots in a 2-column layout
num_plots = len(grouped_nyquist)
num_cols = 2
num_rows = math.ceil(num_plots / num_cols)
figsize = (12, 6 * num_rows)
fig0, axes = plt.subplots(num_rows, num_cols, figsize=figsize)
axes = axes.flatten()

# Function to calculate variance
def calculate_variance(z_real_values):
    return ((max(z_real_values) - min(z_real_values)) / min(z_real_values)) * 100

# Loop through each group and plot
for ax, (group_key, dataframes) in zip(axes, grouped_nyquist.items()):
    z_real_at_min_z_imag = {}
    truncated_dataframes = dataframes[:]
    original_count = len(dataframes)
    
    # Calculate variance
    for i, (key, df) in enumerate(truncated_dataframes):
        # Find index of minimum value in 'Z imag'
        min_index = df['Z imag'].idxmin()
        z_real_at_min_z_imag[key] = df.loc[min_index, 'Z real']
    
    # Calculate percent variance
    var = calculate_variance(list(z_real_at_min_z_imag.values()))
    
    # Store variance results
    variance_results[group_key] = var
    
    # Store truncated nyquist datasets
    for key, df in truncated_dataframes:
        truncated_nyquist[key] = df
    
    # Filter other datasets based on the keys of truncated nyquist datasets
    truncated_keys = set(truncated_nyquist.keys())
    try:
        truncated_R1_opt = {key: value for key, value in R1_opt.items() if key in truncated_keys}
        truncated_Fs1_opt = {key: value for key, value in Fs1_opt.items() if key in truncated_keys}
        truncated_all_experiments = {key: value for key, value in all_experiments.items() if key in truncated_keys}
    except AttributeError as e:
        print(f"Error while filtering: {e}")
        print(f"R1_opt type: {type(R1_opt)}")
        print(f"Fs1_opt type: {type(Fs1_opt)}")
        print(f"all_experiments type: {type(all_experiments)}")
        raise

    # Plot the truncated dataframes
    for i, (key, df) in enumerate(truncated_dataframes):
        color = cmap(norm(key[1])) if i < len(truncated_dataframes) - 1 else "#ff66ff"
        ax.plot(df['Z real'], df['Z imag'], linestyle='none', marker='o', color=color)
    
    # Annotate variance, initial count, and exclusion count on plot
    num_excluded = original_count - len(truncated_dataframes)
    ax.annotate(f'Replicates: {original_count}\nVariance: {var:.2f}\%', 
                xy=(0.1, 0.9), xycoords='axes fraction', ha='left',va='top', fontsize=14, 
                bbox=dict(boxstyle="round,pad=0.3", edgecolor='black', facecolor='white'))
    
    # Set limits for each subplot
    if z_real_at_min_z_imag:
        max_value = max(z_real_at_min_z_imag.values())
        limit = max_value * 1.5
        ax.set(xlim=(0, limit), ylim=(0, limit))
        ax.set_xlabel(f'Z$_{{real}}$ [$\Omega$]')
        ax.set_ylabel(f'-Z$_{{imag}}$ [$\Omega$]')
    ax.set_title(f'{group_key} $^\circ$C')

# Hide any unused axes
for i in range(len(grouped_nyquist), len(axes)):
    fig0.delaxes(axes[i])

fig0.suptitle(materialname, y=1)
plt.tight_layout()
plt.show()

# %%
#set usefilteredvalues to true if you want to use the data that was filtered to satisfy the variance threshold.

usefilteredvalues=False

if usefilteredvalues==True:
    nyquist=filtered_nyquist
    R1_opt=filtered_R1_opt
    Fs1_opt=filtered_Fs1_opt
    all_experiments=filtered_all_experiments
print(R1_opt)
# Out:
# {(30, 8): 402.5279570774032, (30, 9): 402.5279570774032, (30, 10): 402.52361388493085, (35, 7): 329.5867379016215, (35, 8): 329.366632301209, (35, 9): 328.5288113774598, (45, 9): 253.7228149801507, (45, 10): 255.33917313858012, (45, 11): 255.33917313858012, (55, 10): 174.8430011883073, (55, 11): 174.8430011883073, (55, 12): 173.14734701567858, (65, 9): 119.07504648966949, (65, 10): 119.07504648966949, (65, 11): 119.07504648966949, (75, 10): 86.00506362643756, (75, 11): 86.00506362643756, (75, 12): 81.62156339697191, (85, 10): 62.42564576375287, (85, 11): 61.84256773344998, (85, 12): 61.47811704160233, (95, 10): 43.561169671413325, (95, 11): 43.56830340945805, (95, 12): 43.84430596360289}

# %%
#This cell calculates ionic conductivities at each temperature with associated error.

#area calculation

#mm to cm
area = (((diameter)/20)**2)*np.pi
area_err=(((diameter_err)/20)**2)*np.pi
print(area)
#mm to cm
height_cm=height/10
height_cm_err=height_err/10

# Group data by temperature
grouped_R1 = {}
for (temp, replicate), value in R1_opt.items():
    if temp not in grouped_R1:
        grouped_R1[temp] = []
    grouped_R1[temp].append(value)
    

ic={}
ic_err={}
R1={}

for temp, values in grouped_R1.items():
    avg = np.mean(values)
    std_dev = np.std(values)
    R1[temp] = {'average': avg, 'std_dev': std_dev}
    ic[temp]=(1/R1[temp]['average'])*(height_cm/area)
    ic_err[temp]=(math.sqrt(((R1[temp]['std_dev']/R1[temp]['average'])**2)+((height_cm_err/height_cm)**2)+((area_err/area)**2)))*ic[temp]
print(ic)
print(ic_err)



#conductivity calculation (put it in a list then write to a text file)
#for our purposes, this is for exporting the final dataframe
sigma = {}
for key, value in R1_opt.items():
    sigmax = (1/ value)*(height_cm/area)
    sigma[key] = sigmax
    
#print(sigma)    
#print('\u03c3 = {:.2e} S/cm'.format(sigma))

#capacitance calculation
#capacitance = (1/(2*np.pi*R1_opt*fs1_opt))
#print('C = {:.2e} F'.format(capacitance))
# Out:
# 0.2827433388230814
# {30: 0.001840759955681907, 35: 0.0022510421757276724, 45: 0.0029079809806418513, 55: 0.004251572783374501, 65: 0.006222585683137938, 75: 0.008764141550377453, 85: 0.011967202970141127, 95: 0.016971824854820714}
# {30: 8.787091306794108e-07, 35: 3.2969492783570036e-06, 45: 8.806153035378791e-06, 55: 1.9605498709780886e-05, 65: 2.970258257318749e-06, 75: 0.0002142519101097747, 85: 7.564357421831047e-05, 95: 5.188179791058423e-05}

# %%
#define confidence interval calculation
#this function calculates the confidence intervals for relevant parameters in the arrhenius fit
def confidence_interval(alpha, x, y, y_fit):
    from scipy import stats
    #calculate the residual errors for the data (r=(y-ypredicted))
    residuals=y-y_fit
    #print('the residual errors are:',residuals)
    k=8.6173303e-5
    #calculate the total residual error (R=sum(y-ypredicted)^2)
    total_residual_error=sum(residuals**2)
    print('the total residual error is:',total_residual_error)
    
    #calculate the standard deviation about the regression (Sr=rt((total residual error)/(n-2))), n= number of data points
    n=len(x)
    print('the number of data points is:',n)
    dof=n-2
    std_dev_reg=math.sqrt(total_residual_error/dof)
    print('the standard deviation about the regression is:',std_dev_reg)
    
    #calculate the standard deviations in the slope and intercept
    meanx=np.mean(x)
    std_dev_slope=std_dev_reg/math.sqrt((sum((x-meanx)**2)))
    std_dev_int=std_dev_reg*math.sqrt((sum(x**2))/(n*sum((x-meanx)**2)))
    print('the standard deviation in the slope is:',std_dev_slope)
    print('the standard deviation in the intercept is:',std_dev_int)
    
    #calculate the student's t-distribution value
    t_val=stats.t.isf(alpha/2,dof)
    print('the t value is:',t_val)
    
    #calculate the confidence intervals for the slope and intercept
    CI_slope=std_dev_slope*t_val
    print('the',(1-alpha)*100,'% confidence interval for the slope is',model.coef_,'+-',CI_slope)
    CI_int=std_dev_int*t_val
    print('the',(1-alpha)*100,'% confidence interval for the intercept is',model.intercept_,'+-',CI_int)
    
    #calculate uncertainty in activation energy (if m=-E/k, uncertainty in E is uncertainty in m*-1*k)
    CI_E=CI_slope*k
    print('the',(1-alpha)*100,'% confidence interval for the activation energy is',E,'+-',CI_E,'eV')
    return(CI_E,CI_int)

# %%
#generate two bigboi arrays that are just the temperature and ionic conductivities 
ic_array=np.array([])
ic_err_array=np.array([])
t=np.array([])
for key, data in ic.items():
    ic_array=np.append(ic_array,data)
    temp_part=key
    t=np.append(t,temp_part)
    ic_err_array=np.append(ic_err_array,ic_err[key])
t=t.astype(float) #convert temperature strings into floats

print(t,ic_array,ic_err_array)

#manipulate the temperature for our purposes
t_k=t+273.15 #convert to kelvin
tinv=1/t_k #go to inverse temperature for the plotting
x=tinv.reshape((-1,1)) #reshape tinv to being 1 column for the purposes of the fitting

#calculate the natural log of ionic conductivity times temperature. made new variable named y for simplicity in later code
log_ic_t=np.log(ic_array*t_k)
y=log_ic_t #make a new variable called y because y not?

#calculate relative error in the data points, used to weight the fit.
y_err_weighting=(ic_err_array)/(ic_array)

k=8.6173303e-5

#now we do a linear fit of the data, y=mx+b, where ln(ic*T)=y, -E/k=m, 1/T=x,ln(A)=b
model=LinearRegression()
model.fit(x,y,sample_weight=1/y_err_weighting)

#call and print the r^2 value of the fit
r_sq=model.score(x,y,sample_weight=1/y_err_weighting)
print('r^2 value of the fit:',r_sq)

#call and print the y intercept (ln(A))
print('y intercept:',model.intercept_)

#call and print the slope (-E/k)
print('slope:',model.coef_)

#calculate activation energy via m=-E/k-->-m*k=E
E=-1*model.coef_*k
print('the calculated activation energy is:',E,'eV')

#calculate the error values
CI_E,CI_int=confidence_interval(0.05,x,y,model.predict(x))
# Out:
# [30. 35. 45. 55. 65. 75. 85. 95.] [0.00184076 0.00225104 0.00290798 0.00425157 0.00622259 0.00876414
#  0.0119672  0.01697182] [8.78709131e-07 3.29694928e-06 8.80615304e-06 1.96054987e-05
#  2.97025826e-06 2.14251910e-04 7.56435742e-05 5.18817979e-05]
# r^2 value of the fit: 0.9970168505913659
# y intercept: 12.586160371050266
# slope: [-3997.60673081]
# the calculated activation energy is: [0.34448698] eV
# the total residual error is: 0.028013372818807808
# the number of data points is: 8
# the standard deviation about the regression is: 0.06832931632762984
# the standard deviation in the slope is: 467.04379866430287
# the standard deviation in the intercept is: 1.408395461857987
# the t value is: 2.446911848791681
# the 95.0 % confidence interval for the slope is [-3997.60673081] +- 1142.8150048563589
# the 95.0 % confidence interval for the intercept is 12.586160371050266 +- 3.4462195434047405
# the 95.0 % confidence interval for the activation energy is [0.34448698] +- 0.09848014368643349 eV

# %%
#prefactor fun-- we are going to calculate the prefactor and confidence interval here!

#calculate the relative confidence interval in log terms
rel_interval=CI_int/model.intercept_
prefactor=exp(model.intercept_)
absolute_error=prefactor*rel_interval

print(f'the prefactor is {prefactor}({absolute_error}) KS/cm')
# Out:
# the prefactor is 292482.574947444(80084.72291578731) KS/cm

# %%
#calculate 30 degree conductivity and 95% confidence interval

def conductivity_confidence_interval(temp, alpha):
    from scipy import stats
    floattemp=float(temp)
    for key, value in ic.items():
        temp_part=float(key)
        if temp_part==floattemp:
            print(floattemp,'C mean conductivity is:', value, 'S/cm')
            conductivity=value
    std_dev=ic_err[temp]
    
    print('Standard deviation of the conductivities at', floattemp,'C is:', std_dev, 'S/cm')
    
    counter={}
    for key, value in R1_opt.items():
        temp_part=float(key[0])
          # Check if the temperature part is already a key in mean_conductivities
        if temp_part in counter:
            # If it is, add the conductivity value to the existing list
            counter[temp_part].append(value)
            #print('I added something to the counter')
        else:
            # If it's not, create a new entry with a list containing the current resistance value
            counter[temp_part] = [value]
            
    for conductivity_list in counter.items():
        num_rep=len(counter[floattemp])
    print('the number of replicates for',floattemp,'C is:',num_rep)
    dof=num_rep-1
    t_val=stats.t.isf(alpha/2,dof)
    print('t-value is',t_val)
    #moe= margin of error
    moe=(t_val*std_dev)/(sqrt(num_rep))
    return(conductivity, moe)

alpha=0.05
conductivity, moe=conductivity_confidence_interval(30,alpha)

cond_mS=conductivity*1000
moe_mS=moe*1000

print('The',((1-alpha)*100),'% confidence interval for the ionic conductivity is',cond_mS,'+-',moe_mS,'mS/cm')
# Out:
# 30.0 C mean conductivity is: 0.001840759955681907 S/cm
# Standard deviation of the conductivities at 30.0 C is: 8.787091306794108e-07 S/cm
# the number of replicates for 30.0 C is: 3
# t-value is 4.3026527299112765
# The 95.0 % confidence interval for the ionic conductivity is 1.840759955681907 +- 0.0021828344892621658 mS/cm

# %%
#Calculate ln(sigmaT) values

#define T values in Kelvin
Kelvin_temp = [x + 273 for x in target_temperatures]
print(Kelvin_temp)

relative_error={}
for temp in target_temperatures:
     relative_error[temp]=(ic_err[temp])/(ic[temp])

# Create a DataFrame, std dev log is actually a 95% confidence interval but I was too lazy to actually 
finaldf = pd.DataFrame({
    'T': (1 / temp for temp in Kelvin_temp),
    'LnsigmaT': [np.log(ic[temp] * (temp + 273)) for temp in target_temperatures],
    'std_dev_log':[abs(relative_error[temp]*np.log(ic[temp] * (temp + 273))) for temp in target_temperatures]
})
print(finaldf)
# Out:
# [303, 308, 318, 328, 338, 348, 358, 368]
#           T  LnsigmaT   std_dev_log
# 0  0.003300 -0.583844  8.787091e-07
# 1  0.003247 -0.366262  3.296949e-06
# 2  0.003145 -0.078245  8.806153e-06
# 3  0.003049  0.332547  1.960550e-05
# 4  0.002959  0.743476  2.970258e-06
# 5  0.002874  1.115116  2.142519e-04
# 6  0.002793  1.454948  7.564357e-05
# 7  0.002717  1.831882  5.188180e-05

# %%
# Perform linear regression
#slope, intercept, r_value, p_value, std_err = linregress(finaldf['T'], finaldf['LnsigmaT'])

#set the figure size
plt.figure(figsize=(6,6))
plt.xlim(0.0026,0.0034)
blue='#3399ff'
pink='#ff66ff'

# Plotting the data and the regression line
plt.errorbar(finaldf['T'], finaldf['LnsigmaT'], yerr=finaldf['std_dev_log'],xerr=None,color='black', linestyle='none',marker='o',capsize=4)
plt.plot(x,model.predict(x),color=pink,linestyle='solid',linewidth=2)

plt.ylabel(r'ln($\sigma$T) (S$\cdot$cm$^{-1}\cdot$K)')
plt.xlabel('1/T (K$^{-1}$)')
E_mev_round=np.around(E*1000,1)
E_mev_round=''.join(map(str,E_mev_round))

CI_E_mev_round=np.around(CI_E*1000,1)

r_sq_round=np.around(r_sq,4)

showr2='yes'

if showr2=='yes':
    plotlabel=''.join(('E$_a$=',E_mev_round,r'$\pm$',str(CI_E_mev_round),' meV','\nr$^2$=',str(r_sq_round)))
else:              
    plotlabel=''.join(('\n','E$_a$=',E_mev_round,r'$\pm$',str(CI_E_mev_round), ' meV'))

plt.ticklabel_format(axis='x',style='sci',scilimits=(0,0))

plt.figtext(0.95,0.95,plotlabel ,horizontalalignment='right',verticalalignment='top',)
plt.tight_layout()
plt.show()
# Set the fontsize of the tick labels


# Displaying the legend
#plt.legend()

# Show the plot

# Display regression statistics
#print(f"Slope: {slope}")
#print(f"Intercept: {intercept}")
#print(f"R-squared value: {r_value**2}")
#print(f"P-value: {p_value}")

# %%
#Generate a pandas dataframe with all the relevant parameters from the fit

#modify samplename and materialname as appropriate
samplename='1-107A Pellet 2 last 3 datasets'
materialname='SSM Li$_6$PS$_5$Cl'

slope=[float(model.coef_)]*len(finaldf)
intercept=[model.intercept_]*len(finaldf)
Ea=[float(E)]*len(finaldf)
CI_Ea=[CI_E]*len(finaldf)
samplenamez=[samplename]*len(finaldf)
materialnamez=[materialname]*len(finaldf)
r_sqs=[r_sq]*len(finaldf)
conductivityz=[conductivity]*len(finaldf)
moez=[moe]*len(finaldf)
moez_prefactor=[absolute_error]*len(finaldf)
meanz_prefactor=[prefactor]*len(finaldf)

exportdf = pd.DataFrame({
    'T':target_temperatures,
    '1/T': finaldf['T'],
    'LnsigmaT': finaldf['LnsigmaT'],
    'std_dev_ln':finaldf['std_dev_log'],
    'slope':slope,
    'intercept':intercept,
    'r_squared':r_sqs,
    'Ea':Ea,
    'CI_Ea':CI_Ea,
    'sample_name':samplenamez,
    'material_name':materialnamez,
    '30c conductivity':conductivityz,
    '30c conductivity MOE':moez,
    'Prefactor':meanz_prefactor,
    'Prefactor MOE':moez_prefactor
})

print(exportdf)
# Out:
#     T       1/T  LnsigmaT    std_dev_ln        slope  intercept  r_squared  \
# 0  30  0.003300 -0.583844  8.787091e-07 -3997.606731   12.58616   0.997017
# 1  35  0.003247 -0.366262  3.296949e-06 -3997.606731   12.58616   0.997017
# 2  45  0.003145 -0.078245  8.806153e-06 -3997.606731   12.58616   0.997017
# 3  55  0.003049  0.332547  1.960550e-05 -3997.606731   12.58616   0.997017
# 4  65  0.002959  0.743476  2.970258e-06 -3997.606731   12.58616   0.997017
# 5  75  0.002874  1.115116  2.142519e-04 -3997.606731   12.58616   0.997017
# 6  85  0.002793  1.454948  7.564357e-05 -3997.606731   12.58616   0.997017
# 7  95  0.002717  1.831882  5.188180e-05 -3997.606731   12.58616   0.997017
#
#          Ea    CI_Ea                      sample_name       material_name  \
# 0  0.344487  0.09848  1-107A Pellet 2 last 3 datasets  SSM Li$_6$PS$_5$Cl
# 1  0.344487  0.09848  1-107A Pellet 2 last 3 datasets  SSM Li$_6$PS$_5$Cl
# 2  0.344487  0.09848  1-107A Pellet 2 last 3 datasets  SSM Li$_6$PS$_5$Cl
# 3  0.344487  0.09848  1-107A Pellet 2 last 3 datasets  SSM Li$_6$PS$_5$Cl
# 4  0.344487  0.09848  1-107A Pellet 2 last 3 datasets  SSM Li$_6$PS$_5$Cl
# 5  0.344487  0.09848  1-107A Pellet 2 last 3 datasets  SSM Li$_6$PS$_5$Cl
# 6  0.344487  0.09848  1-107A Pellet 2 last 3 datasets  SSM Li$_6$PS$_5$Cl
# 7  0.344487  0.09848  1-107A Pellet 2 last 3 datasets  SSM Li$_6$PS$_5$Cl
#
#    30c conductivity  30c conductivity MOE      Prefactor  Prefactor MOE
# 0          0.001841              0.000002  292482.574947   80084.722916
# 1          0.001841              0.000002  292482.574947   80084.722916
# 2          0.001841              0.000002  292482.574947   80084.722916
# 3          0.001841              0.000002  292482.574947   80084.722916
# 4          0.001841              0.000002  292482.574947   80084.722916
# 5          0.001841              0.000002  292482.574947   80084.722916
# 6          0.001841              0.000002  292482.574947   80084.722916
# 7          0.001841              0.000002  292482.574947   80084.722916

# %%
#save the dataframe generated in the previous cell

#filter non-alphanumeric and space characters from the material name so that it's easier to deal with from a file management perspective
cleaned_matname = filter(lambda x: x.isalnum() or x.isspace(), materialname)

# filter returns a generator, so we need to re-join the string
cleaned_matname = "".join(cleaned_matname)

#THIS IS WHERE THE ARRHENIUS AND SUMMARY DATA WILL BE SAVED
saveloc_DIR='C:/Users/austi/OneDrive - Colorado School of Mines/Research/Data/EIS/Data/Exported Arrhenius Fits'

subfolds=''

saveloc=''.join((saveloc_DIR,subfolds))

filename=''.join((saveloc,'/',samplename,' ',cleaned_matname,' Arrhenius and Summary Plot.csv'))
readytosave=True

if readytosave==True:
    if not os.path.isdir(saveloc):
        os.makedirs(saveloc_DIR)
    exportdf.to_csv(filename)

# %%
#This cell generates a table of echem data that can be pasted into latex!

#leading resistor
R1={}
#parallel Resistor
R2={}
#parallel constant phase element
Q2={}
n2={}
#tailing constant phase element
Q3={}
n3={}

capacitance={}
char_freq={}

for key, exp_instance in all_experiments.items():
    R1[key]=float(exp_instance.fit_Rs[0])
    R2[key]=float(exp_instance.fit_R1[0])
    n2[key]=float(exp_instance.fit_n1[0])
    Q2[key]=((1/(2*3.14159*float(exp_instance.fit_fs1[0])))**float(exp_instance.fit_n1[0]))/float(exp_instance.fit_R1[0])
    capacitance[key]=(((Q2[key]*R2[key])**(1/n2[key]))/R2[key])
    char_freq[key]=float(exp_instance.fit_fs1[0])
    n3[key]=float(exp_instance.fit_n[0])
    Q3[key]=float(exp_instance.fit_Q[0])
    
    
#print(R2)
# Create a mapping from old keys to new keys

new_keys_mapping = {}
counters = {}

for key in R2.keys():
    if key[0] not in counters:
        counters[key[0]] = 1
    new_keys_mapping[key] = (key[0], counters[key[0]])
    counters[key[0]] += 1

# Function to reindex dictionaries based on new_keys_mapping
def reindex_dict(original_dict):
    new_dict = {}
    for old_key, value in original_dict.items():
        new_key = new_keys_mapping[old_key]
        new_dict[new_key] = value
    return new_dict

# Reindex all dictionaries
R1_new = reindex_dict(R1)
R2_new = reindex_dict(R2)
n2_new = reindex_dict(n2)
Q2_new = reindex_dict(Q2)
n3_new = reindex_dict(n3)
Q3_new = reindex_dict(Q3)
sigma_new=reindex_dict(sigma)
capacitance_new=reindex_dict(capacitance)
char_freq_new=reindex_dict(char_freq)
reindexed_experiments=reindex_dict(all_experiments)

#print(reindexed_experiments)
#print(R2_new)

# Combine reindexed dictionaries into a single DataFrame
refinedparams = {
    r'$T$ ($^\circ$C)': [key[0] for key in R1_new.keys()],
    'Replicate Scan': [key[1] for key in R1_new.keys()],
    r'R$_0$ ($\Omega$)': list(R1_new.values()),
    r'$R_1$ ($\Omega$)': list(R2_new.values()),
    r'$\sigma$ (S cm$^{-1}$)':list(sigma_new.values()),
    r'$n_1$': list(n2_new.values()),
    r'$Q_1$(S/s$^n$)': list(Q2_new.values()),
    r'$C_1$ (F)': list(capacitance_new.values()),
    r'$\tau_{1}$ (Hz)': list(char_freq_new.values()),
    r'$n_2$': list(n3_new.values()),
    r'$Q_2$(S/s$^n$)': list(Q3_new.values())
    
}

refinedparams = pd.DataFrame(refinedparams)


# Create a figure and add the DataFrame as a table
fig, ax = plt.subplots(figsize=(12, 5))  # Set the figure size as needed
ax.axis('off')  # Hide the axes

#roundedrefinedparams=refinedparams.round(2)
def scientific_notation(x):
    return f"{x:.2e}"


columns_to_sci = [r'R$_0$ ($\Omega$)',r'$R_1$ ($\Omega$)',r'$Q_1$(S/s$^n$)',r'$C_1$ (F)',r'$Q_2$(S/s$^n$)',r'$\sigma$ (S cm$^{-1}$)',r'$\tau_{1}$ (Hz)']
refinedparams[columns_to_sci] = refinedparams[columns_to_sci].applymap(scientific_notation)
columns_to_round=[r'$n_1$',r'$n_2$']
refinedparams[columns_to_round]=refinedparams[columns_to_round].round(2)
#Add '&' columns and '\' at the end of each row
for col in refinedparams.columns[:-1]:
    refinedparams.insert(refinedparams.columns.get_loc(col)+1, '&', '&',allow_duplicates=True)

# Add the '\\' column at the end
refinedparams['\\\\'] = '\\\\'
display(refinedparams)
# Add the table to the plot
#table = ax.table(cellText=refinedparams.values, colLabels=refinedparams.columns, cellLoc='center', loc='center')
#ax.set_title(materialname)
# Initialize a list to store formatted rows
formatted_rows = []

# Loop through each row in the DataFrame
#for _, row in refinedparams.iterrows():
    # Join each row value with '&', then add '\\' at the end
    #formatted_row = ' & '.join(row.astype(str)) + r' \\'
    #formatted_rows.append(formatted_row)

# Combine all rows into the final table string
#latex_table = '\n'.join(formatted_rows)

# Print the LaTeX table string
#print(latex_table)
# Style the table
#table.auto_set_font_size(False)
#table.autofit=True
#table.set_fontsize(10)
#table.scale(1.2, 1.2)  # Adjust the scaling as needed

#plt.show()

#this is the repository for all our temp dependent nyquists!
params_saveloc_DIR='C:/Users/austi/OneDrive - Colorado School of Mines/Research/Data/EIS/Data/Fitted Parameters'
#this will be the folder into which we whang all of the dataframes, named based on the sample and material name
params_filename=f"{samplename}_{cleaned_matname}_refinedparameters.csv"


#here we save all of our dataframes! don't want to miss out on any yummy data, so we save it all
#the save format is temp_30_replicate_1_1-107A Pellet 2_SSM Li6PS5Cl, obviously different if your materials aren't exactly like mine
readytosave=True
if readytosave==True:
    if not os.path.isdir(params_saveloc_DIR):
        os.makedirs(params_saveloc_DIR)
    refinedparams.to_csv(f"{params_saveloc_DIR}/{params_filename}")
# Out:
#     $T$ ($^\circ$C)  &  Replicate Scan  & R$_0$ ($\Omega$)  &  \
# 0                30  &               1  &         0.00e+00  &
# 1                30  &               2  &         0.00e+00  &
# 2                30  &               3  &         0.00e+00  &
# 3                35  &               1  &         0.00e+00  &
# 4                35  &               2  &         0.00e+00  &
# 5                35  &               3  &         0.00e+00  &
# 6                45  &               1  &         0.00e+00  &
# 7                45  &               2  &         0.00e+00  &
# 8                45  &               3  &         0.00e+00  &
# 9                55  &               1  &         0.00e+00  &
# 10               55  &               2  &         0.00e+00  &
# 11               55  &               3  &         0.00e+00  &
# 12               65  &               1  &         0.00e+00  &
# 13               65  &               2  &         0.00e+00  &
# 14               65  &               3  &         0.00e+00  &
# 15               75  &               1  &         0.00e+00  &
# 16               75  &               2  &         0.00e+00  &
# 17               75  &               3  &         0.00e+00  &
# 18               85  &               1  &         0.00e+00  &
# 19               85  &               2  &         0.00e+00  &
# 20               85  &               3  &         0.00e+00  &
# 21               95  &               1  &         0.00e+00  &
# 22               95  &               2  &         0.00e+00  &
# 23               95  &               3  &         0.00e+00  &
#
#    $R_1$ ($\Omega$)  & $\sigma$ (S cm$^{-1}$)  &  ...  $Q_1$(S/s$^n$)  &  \
# 0          4.03e+02  &               1.84e-03  &  ...        1.58e-11  &
# 1          4.03e+02  &               1.84e-03  &  ...        1.58e-11  &
# 2          4.03e+02  &               1.84e-03  &  ...        1.83e-11  &
# 3          3.30e+02  &               2.25e-03  &  ...        1.67e-08  &
# 4          3.29e+02  &               2.25e-03  &  ...        1.72e-08  &
# 5          3.29e+02  &               2.26e-03  &  ...        1.77e-08  &
# 6          2.54e+02  &               2.92e-03  &  ...        5.30e-08  &
# 7          2.55e+02  &               2.90e-03  &  ...        5.42e-08  &
# 8          2.55e+02  &               2.90e-03  &  ...        5.42e-08  &
# 9          1.75e+02  &               4.24e-03  &  ...        7.30e-08  &
# 10         1.75e+02  &               4.24e-03  &  ...        7.30e-08  &
# 11         1.73e+02  &               4.28e-03  &  ...        7.15e-08  &
# 12         1.19e+02  &               6.22e-03  &  ...        6.06e-08  &
# 13         1.19e+02  &               6.22e-03  &  ...        6.06e-08  &
# 14         1.19e+02  &               6.22e-03  &  ...        6.06e-08  &
# 15         8.60e+01  &               8.62e-03  &  ...        4.18e-08  &
# 16         8.60e+01  &               8.62e-03  &  ...        4.18e-08  &
# 17         8.16e+01  &               9.08e-03  &  ...        3.75e-08  &
# 18         6.24e+01  &               1.19e-02  &  ...        1.13e-11  &
# 19         6.18e+01  &               1.20e-02  &  ...        9.88e-12  &
# 20         6.15e+01  &               1.21e-02  &  ...        9.60e-12  &
# 21         4.36e+01  &               1.70e-02  &  ...        4.09e-12  &
# 22         4.36e+01  &               1.70e-02  &  ...        4.90e-12  &
# 23         4.38e+01  &               1.69e-02  &  ...        4.06e-12  &
#
#    $C_1$ (F)  & $\tau_{1}$ (Hz)  & $n_2$  &  $Q_2$(S/s$^n$)  \\
# 0   1.58e-11  &        2.50e+07  &  0.68  &        2.30e-07  \\
# 1   1.58e-11  &        2.50e+07  &  0.68  &        2.30e-07  \\
# 2   1.58e-11  &        2.51e+07  &  0.68  &        2.30e-07  \\
# 3   5.21e-12  &        9.26e+07  &  0.67  &        3.49e-07  \\
# 4   5.48e-12  &        8.82e+07  &  0.67  &        3.49e-07  \\
# 5   5.73e-12  &        8.45e+07  &  0.67  &        3.50e-07  \\
# 6   3.00e-11  &        2.09e+07  &  0.75  &        2.24e-07  \\
# 7   3.12e-11  &        2.00e+07  &  0.76  &        2.06e-07  \\
# 8   3.12e-11  &        2.00e+07  &  0.76  &        2.06e-07  \\
# 9   3.99e-11  &        2.28e+07  &  0.85  &        9.05e-08  \\
# 10  3.99e-11  &        2.28e+07  &  0.85  &        9.05e-08  \\
# 11  3.83e-11  &        2.40e+07  &  0.86  &        8.67e-08  \\
# 12  2.26e-11  &        5.91e+07  &  0.89  &        7.11e-08  \\
# 13  2.26e-11  &        5.91e+07  &  0.89  &        7.11e-08  \\
# 14  2.26e-11  &        5.91e+07  &  0.89  &        7.11e-08  \\
# 15  9.82e-12  &        1.88e+08  &  0.90  &        8.01e-08  \\
# 16  9.82e-12  &        1.88e+08  &  0.90  &        8.01e-08  \\
# 17  7.92e-12  &        2.46e+08  &  0.90  &        8.36e-08  \\
# 18  1.13e-11  &        2.26e+08  &  0.88  &        1.25e-07  \\
# 19  9.88e-12  &        2.60e+08  &  0.88  &        1.27e-07  \\
# 20  9.58e-12  &        2.70e+08  &  0.88  &        1.29e-07  \\
# 21  4.06e-12  &        9.00e+08  &  0.85  &        2.35e-07  \\
# 22  4.06e-12  &        9.00e+08  &  0.85  &        2.36e-07  \\
# 23  4.06e-12  &        8.95e+08  &  0.85  &        2.41e-07  \\
#
# [24 rows x 22 columns]

# %%
#in this cell, we generate simulated data for each nyquist plot so as to be able to export experimental and modeled values
#for temperature dependent nyquist plots

#generates a frequency range for any simulations
f_range = freq_gen(f_start=(2*10**6), f_stop=0.2, pts_decade=10)
print(f_range[0][:4]) #First 5 points in the freq. array
print()
print(f_range[1][:4]) #First 5 points in the angular freq. array


#This chunk of code generates a simulated dataset using the parameters from the initial modelling above
sim={}

# Iterate through the outer dictionary (temperature-wise experiments)
for key, exp_instance in reindexed_experiments.items():
        sim_temp= cir_RsRQQ(w=f_range[1], Rs=float(exp_instance.fit_Rs[0]), R1=float(exp_instance.fit_R1[0]), n1=float(exp_instance.fit_n1[0]), Q1=((1/(2*3.14159*float(exp_instance.fit_fs1[0])))**float(exp_instance.fit_n1[0]))/float(exp_instance.fit_R1[0]), n=float(exp_instance.fit_n[0]), Q=float(exp_instance.fit_Q[0]))
        sim[key]=sim_temp
# Out:
# [2000000.         1583363.8318526  1253520.51200948  992389.52060058]
#
# [12566370.61435917  9948568.36421585  7876101.66330618  6235367.25483656]

# %%
    
#here we make a bunch of dataframes with all of the info we need for nyquist plots
nyquistdf={}
# Iterate through the outer dictionary (temperature-wise experiments)
for key, exp_instance in reindexed_experiments.items():
        min_length = min(len(exp_instance.df_raw.re), len(exp_instance.df_raw.im), len(sim[key].real), len(sim[key].imag),len(exp_instance.df_raw.f))
        key_temp=[key]*min_length
        samplenamez=[samplename]*min_length
        materialnamez=[materialname]*min_length
        diameterz=[diameter]*min_length
        heightz=[height]*min_length
        # Truncate arrays to the minimum length
        truncated_re = exp_instance.df_raw.re[:min_length]
        truncated_im = exp_instance.df_raw.im[:min_length]
        truncated_f= exp_instance.df_raw.f[:min_length]
        truncated_fit_real = sim[key].real[:min_length]
        truncated_fit_imag = -sim[key].imag[:min_length]
        
        # Create DataFrame with truncated arrays
        nyquistdf[key] = pd.DataFrame({
            'Frequency':truncated_f,
            'Z real': truncated_re,
            'Z imag': truncated_im,
            'Fit real': truncated_fit_real,
            'Fit imag': truncated_fit_imag,
            'Dataset':key_temp,
            'sample_name':samplenamez,
            'material_name':materialnamez,
            'height':heightz,
            'diameter':diameterz
        })
print(nyquistdf)
#this is the repository for all our temp dependent nyquists!
nyquist_saveloc_DIR='C:/Users/austi/OneDrive - Colorado School of Mines/Research/Data/EIS/Data/Temperature Dependent Nyquist'
#this will be the folder into which we whang all of the dataframes, named based on the sample and material name
save_location=''.join((nyquist_saveloc_DIR,'/',samplename,' ',cleaned_matname))


#here we save all of our dataframes! don't want to miss out on any yummy data, so we save it all
#the save format is temp_30_replicate_1_1-107A Pellet 2_SSM Li6PS5Cl, obviously different if your materials aren't exactly like mine
readytosave=True
if readytosave==True:
    for key,df in nyquistdf.items():
        filename=f"temp_{key[0]}_replicate_{key[1]}_{samplename}_{cleaned_matname}.csv"
        if not os.path.isdir(save_location):
            os.makedirs(save_location)
        df.to_csv(f"{save_location}/{filename}")
# Out:
# {(30, 1):        Frequency        Z real        Z imag      Fit real      Fit imag  \
# 0   2.000039e+06  4.392097e+02  1.026229e+02  4.337075e+02  9.235214e+01
# 1   1.588711e+06  4.488054e+02  1.039017e+02  4.404243e+02  9.608743e+01
# 2   1.261992e+06  4.576293e+02  1.056583e+02  4.477756e+02  1.029329e+02
# 3   1.002539e+06  4.661601e+02  1.105719e+02  4.560603e+02  1.129257e+02
# 4   7.962891e+05  4.741133e+02  1.194632e+02  4.655579e+02  1.262024e+02
# ..           ...           ...           ...           ...           ...
# 65  6.334459e-01  1.841914e+06  7.711802e+06  9.649760e+05  1.727401e+06
# 66  5.029507e-01  2.319126e+06  9.375742e+06  1.129922e+06  2.022794e+06
# 67  3.999573e-01  2.917845e+06  1.136840e+07  1.323075e+06  2.368700e+06
# 68  3.175813e-01  3.678387e+06  1.377979e+07  1.549258e+06  2.773758e+06
# 69  2.520161e-01  4.642028e+06  1.668175e+07  1.814119e+06  3.248083e+06
#
#     Dataset                      sample_name       material_name  height  \
# 0   (30, 1)  1-107A Pellet 2 last 3 datasets  SSM Li$_6$PS$_5$Cl   2.095
# 1   (30, 1)  1-107A Pellet 2 last 3 datasets  SSM Li$_6$PS$_5$Cl   2.095
# 2   (30, 1)  1-107A Pellet 2 last 3 datasets  SSM Li$_6$PS$_5$Cl   2.095
# 3   (30, 1)  1-107A Pellet 2 last 3 datasets  SSM Li$_6$PS$_5$Cl   2.095
# 4   (30, 1)  1-107A Pellet 2 last 3 datasets  SSM Li$_6$PS$_5$Cl   2.095
# ..      ...                              ...                 ...     ...
# 65  (30, 1)  1-107A Pellet 2 last 3 datasets  SSM Li$_6$PS$_5$Cl   2.095
# 66  (30, 1)  1-107A Pellet 2 last 3 datasets  SSM Li$_6$PS$_5$Cl   2.095
# 67  (30, 1)  1-107A Pellet 2 last 3 datasets  SSM Li$_6$PS$_5$Cl   2.095
# 68  (30, 1)  1-107A Pellet 2 last 3 datasets  SSM Li$_6$PS$_5$Cl   2.095
# 69  (30, 1)  1-107A Pellet 2 last 3 datasets  SSM Li$_6$PS$_5$Cl   2.095
#
#     diameter
# 0          6
# 1          6
# 2          6
# 3          6
# 4          6
# ..       ...
# 65         6
# 66         6
# 67         6
# 68         6
# 69         6
#
# [70 rows x 10 columns], (30, 2):        Frequency        Z real        Z imag      Fit real      Fit imag  \
# 0   2.000039e+06